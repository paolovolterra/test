# %% [markdown]
# # Introduction to DBnomics in Python

# %% [markdown]
# This tutorial explains how to obtain economic [time series](https://en.wikipedia.org/wiki/Time_series) from [DBnomics](https://db.nomics.world/), how to manipulate them and how to visualize them.
#
# We will use well-known Python packages to achieve our goal, like [Pandas](http://pandas.pydata.org/) to represent tabular data, and [Altair](https://altair-viz.github.io/) to create the charts.
#
# We will also use the [`dbnomics` Python package](https://git.nomics.world/dbnomics/dbnomics-python-client) to obtain data from the DBnomics Web API.
#
# First, let's import those libraries:

# %%
import altair as alt
alt.renderers.enable('default')
from altair import Chart, Scale, Y

# %%
import pandas as pd
from dbnomics import fetch_series, fetch_series_by_api_link

# %% [markdown]
# Note: in this notebook we are going to follow the conventions of the Scientific Python community. In particular, the `df` shortcut for `DataFrame`.

# %% [markdown]
# ## Fetch one time series by code

# %% [markdown]
# First, let's assume that we know which series we want to download. A series identifier (ID) is defined by three values, formatted like this: `provider_code/dataset_code/series_code`. We can use the `fetch_series` function, previously imported from the `dbnomics` Python package.
#
# For example, to fetch the time series `EA19.1.0.0.0.ZUTN` from the ["Unemployment rate" [ZUTN] dataset](https://db.nomics.world/AMECO/ZUTN) belonging to the [AMECO provider](https://db.nomics.world/AMECO):

# %%
df1 = fetch_series('AMECO/ZUTN/EA19.1.0.0.0.ZUTN')

# %% [markdown]
# The returned data is stored in the `df1` variable. Its type is a [Pandas](http://pandas.pydata.org/) [`DataFrame`](https://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe).
#
# Now let's display the first rows of this `DataFrame` by using the `head` method, each row representing an observation of the time series:

# %%
df1.head()
# Out:
#   @frequency provider_code dataset_code  \
# 0     annual         AMECO         ZUTN
# 1     annual         AMECO         ZUTN
# 2     annual         AMECO         ZUTN
# 3     annual         AMECO         ZUTN
# 4     annual         AMECO         ZUTN
#
#                                         dataset_name        series_code  \
# 0  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 1  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 2  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 3  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 4  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
#
#                                          series_name original_period  \
# 0  Annually – (Percentage of active population) –...            1960
# 1  Annually – (Percentage of active population) –...            1961
# 2  Annually – (Percentage of active population) –...            1962
# 3  Annually – (Percentage of active population) –...            1963
# 4  Annually – (Percentage of active population) –...            1964
#
#       period original_value  value freq                             unit  \
# 0 1960-01-01             NA    NaN    a  percentage-of-active-population
# 1 1961-01-01             NA    NaN    a  percentage-of-active-population
# 2 1962-01-01             NA    NaN    a  percentage-of-active-population
# 3 1963-01-01             NA    NaN    a  percentage-of-active-population
# 4 1964-01-01             NA    NaN    a  percentage-of-active-population
#
#     geo Frequency                               Unit                   Country
# 0  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 1  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 2  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 3  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 4  ea19  Annually  (Percentage of active population)  Euro area (19 countries)

# %% [markdown]
# In such `DataFrame`, you will always find at least those columns:
#
# - `@frequency`: (harmonized frequency generated by DBnomics)
# - `provider_code`
# - `dataset_code`
# - `dataset_name`
# - `series_code`
# - `series_name`
# - `original_period`: the period as returned by DBnomics
# - `period` (`pd.Timestamp`): the first day of `original_period`
# - `original_value` (`str` or `float`): the observation value as returned by DBnomics, where not available values are represented by `"NA"`
# - `value` (`float` or `np.NaN`): the observation value as returned by DBnomics, where not available values are represented by `np.NaN`
#
# Followed by dimensions columns, corresponding to the dimensions of the dataset:
#
# - _dimensions labels_. In df1 we have `freq`, `unit` and `geo`
# - then _dimensions values labels_. In df1 we have `Frequency`, `Unit` and `Country`

# %%
df1['value'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Here we use the [Altair](https://altair-viz.github.io/) library to render charts, but you can use any other one like matplotlib, bqplot, plotly, etc.
#
# The time series contains "NA" (not available) values in the `value` column, represented by `NaN` values. We remove them to make sure the chart takes most of the available space.

# %%
chart = Chart(df1[df1.value.notna()]).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fetch two time series by code

# %% [markdown]
# Again, let's assume that we know which series we want to download. We can reuse the `fetch_series` function, this time with two series codes.
#
# For example, to fetch the time series `EA19.1.0.0.0.ZUTN` and `DNK.1.0.0.0.ZUTN` from the ["Unemployment rate" [ZUTN] dataset](https://db.nomics.world/AMECO/ZUTN) belonging to the [AMECO provider](https://db.nomics.world/AMECO):

# %%
df2 = fetch_series([
    'AMECO/ZUTN/EA19.1.0.0.0.ZUTN',
    'AMECO/ZUTN/DNK.1.0.0.0.ZUTN',
])
df2.head()
# Out:
#   @frequency provider_code dataset_code  \
# 0     annual         AMECO         ZUTN
# 1     annual         AMECO         ZUTN
# 2     annual         AMECO         ZUTN
# 3     annual         AMECO         ZUTN
# 4     annual         AMECO         ZUTN
#
#                                         dataset_name        series_code  \
# 0  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 1  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 2  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 3  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 4  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
#
#                                          series_name original_period  \
# 0  Annually – (Percentage of active population) –...            1960
# 1  Annually – (Percentage of active population) –...            1961
# 2  Annually – (Percentage of active population) –...            1962
# 3  Annually – (Percentage of active population) –...            1963
# 4  Annually – (Percentage of active population) –...            1964
#
#       period original_value  value freq                             unit  \
# 0 1960-01-01             NA    NaN    a  percentage-of-active-population
# 1 1961-01-01             NA    NaN    a  percentage-of-active-population
# 2 1962-01-01             NA    NaN    a  percentage-of-active-population
# 3 1963-01-01             NA    NaN    a  percentage-of-active-population
# 4 1964-01-01             NA    NaN    a  percentage-of-active-population
#
#     geo Frequency                               Unit                   Country
# 0  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 1  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 2  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 3  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 4  ea19  Annually  (Percentage of active population)  Euro area (19 countries)

# %%
chart = Chart(df2.query("period >= '2000'")).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fetch time series by code mask

# %% [markdown]
# The code mask notation is a very concise way to select one or many time series at once. It is not compatible with all the providers (see [this list](https://git.nomics.world/dbnomics/dbnomics-api/blob/293603323b907ed3200580ab0ebe01ce60789972/dbnomics_api/application.cfg#L21)).
#
# Quick description: given 3 dimensions "frequency", "country" and "indicator", you can select:
#
# - one time series by giving its code: `"M.FR.PCPIEC_IX"`
# - many series by enumerating dimensions codes: `"M.FR+DE.PCPIEC_IX"` is equivalent to `["M.FR.PCPIEC_IX", "M.DE.PCPIEC_IX"]`
# - many series by skipping a dimension, repeating `"."` in the code mask: `"M..PCPIEC_IX"` is equivalent to `["M.country1.PCPIEC_IX", "M.country2.PCPIEC_IX", ..., "M.countryN.PCPIEC_IX"]`

# %%
code_mask_df = fetch_series("IMF", "CPI", series_code="M.FR+DE.PCPIEC_IX+PCPIA_IX")
code_mask_df = code_mask_df.query("period >= '2000' and period < '2002'")
code_mask_df.head()
# Out:
#     @frequency provider_code dataset_code                dataset_name  \
# 540    monthly           IMF          CPI  Consumer Price Index (CPI)
# 541    monthly           IMF          CPI  Consumer Price Index (CPI)
# 542    monthly           IMF          CPI  Consumer Price Index (CPI)
# 543    monthly           IMF          CPI  Consumer Price Index (CPI)
# 544    monthly           IMF          CPI  Consumer Price Index (CPI)
#
#        series_code                                series_name original_period  \
# 540  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear         2000-01
# 541  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear         2000-02
# 542  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear         2000-03
# 543  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear         2000-04
# 544  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear         2000-05
#
#         period original_value     value FREQ REF_AREA INDICATOR Frequency  \
# 540 2000-01-01       91.66486  91.66486    M       DE  PCPIA_IX   Monthly
# 541 2000-02-01       91.47855  91.47855    M       DE  PCPIA_IX   Monthly
# 542 2000-03-01       91.66486  91.66486    M       DE  PCPIA_IX   Monthly
# 543 2000-04-01       91.75802  91.75802    M       DE  PCPIA_IX   Monthly
# 544 2000-05-01       91.66486  91.66486    M       DE  PCPIA_IX   Monthly
#
#     Reference Area              Indicator
# 540        Germany  Clothing and footwear
# 541        Germany  Clothing and footwear
# 542        Germany  Clothing and footwear
# 543        Germany  Clothing and footwear
# 544        Germany  Clothing and footwear

# %%
chart = Chart(code_mask_df).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fetch time series by dimension

# %% [markdown]
# Searching by dimension is a less concise way to select time series than using the code mask, but it's universal: some fetchers are not compatible with the code mask notation.
#
# The following example fetches many series from the ["Doing Business" [DB]](https://db.nomics.world/WB/DB) dataset of the [World Bank](https://db.nomics.world/WB) provider, selecting for time series about France, Italy and Spain (`country` dimension), and the indicator "Procedures required to start a business - Women (number)" (`indicator` dimension):

# %%
df3 = fetch_series("WB", "DBS", dimensions={
    "country": ["FR", "IT", "ES"],
    "indicator": ["IC.REG.COST.PC.FE.ZS.DRFN"],
})
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# To know the codes of the time series you got:

# %%
df3.series_code.unique().tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17372\2580641390.py in ?()
# ----> 1 df3.series_code.unique().tolist()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'series_code'

# %%
chart = Chart(df3).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\schema\channels.py:209, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#     202 if isinstance(data, nw.DataFrame):
#     203     msg = (
#     204         f'Unable to determine data type for the field "{shorthand}";'
#     205         " verify that the field name is not misspelled."
#     206         " If you are referencing a field from a transform,"
#     207         " also confirm that the data type is specified correctly."
#     208     )
# --> 209     raise ValueError(msg)
#     210 else:
#     211     msg = (
#     212         f"{shorthand} encoding field is specified without a type; "
#     213         "the type cannot be automatically inferred because "
#     214         "the data is not specified as a pandas.DataFrame."
#     215     )
#
# ValueError: Unable to determine data type for the field "series_code"; verify that the field name is not misspelled. If you are referencing a field from a transform, also confirm that the data type is specified correctly.
# alt.Chart(...)

# %% [markdown]
# ## Fetch time series by API link

# %% [markdown]
# When you don't know the codes of the dimensions, provider, dataset or series, you can:
#
# - go to the page of a dataset on DBnomics website, for example [Doing Business](https://db.nomics.world/WB/DB),
# - select some dimensions by using the input widgets of the left column,
# - click on "Copy API link" in the menu of the "Download" button,
# - use the `fetch_series_by_api_link` function such as below.

# %%
df4 = fetch_series_by_api_link("https://api.db.nomics.world/v22/series/WB/DBS?observations=1&dimensions=%7B%22country%22%3A%5B%22FR%22%2C%22IT%22%2C%22ES%22%5D%2C%22indicator%22%3A%5B%22IC.REG.COST.PC.FE.ZS.DRFN%22%5D%7D")
df4.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
chart = Chart(df4).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\schema\channels.py:209, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#     202 if isinstance(data, nw.DataFrame):
#     203     msg = (
#     204         f'Unable to determine data type for the field "{shorthand}";'
#     205         " verify that the field name is not misspelled."
#     206         " If you are referencing a field from a transform,"
#     207         " also confirm that the data type is specified correctly."
#     208     )
# --> 209     raise ValueError(msg)
#     210 else:
#     211     msg = (
#     212         f"{shorthand} encoding field is specified without a type; "
#     213         "the type cannot be automatically inferred because "
#     214         "the data is not specified as a pandas.DataFrame."
#     215     )
#
# ValueError: Unable to determine data type for the field "series_code"; verify that the field name is not misspelled. If you are referencing a field from a transform, also confirm that the data type is specified correctly.
# alt.Chart(...)

# %% [markdown]
# The chart is exactly the same than the previous one.

# %% [markdown]
# ## Fetch time series from the cart

# %% [markdown]
# On the [cart page](https://db.nomics.world/cart) of the DBnomics website, click on "Copy API link" and copy-paste it as an argument of the `fetch_series_by_api_link` function.
#
# Please note that when you update your cart, you have to copy this link again, because the link itself contains the IDs of the series in the cart.

# %%
cart_df = fetch_series_by_api_link("https://api.db.nomics.world/v22/series?series_ids=AMECO%2FZUTN%2FEA19.1.0.0.0.ZUTN&observations=1")
cart_df.head()
# Out:
#   @frequency provider_code dataset_code  \
# 0     annual         AMECO         ZUTN
# 1     annual         AMECO         ZUTN
# 2     annual         AMECO         ZUTN
# 3     annual         AMECO         ZUTN
# 4     annual         AMECO         ZUTN
#
#                                         dataset_name        series_code  \
# 0  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 1  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 2  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 3  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 4  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
#
#                                          series_name original_period  \
# 0  Annually – (Percentage of active population) –...            1960
# 1  Annually – (Percentage of active population) –...            1961
# 2  Annually – (Percentage of active population) –...            1962
# 3  Annually – (Percentage of active population) –...            1963
# 4  Annually – (Percentage of active population) –...            1964
#
#       period original_value  value freq                             unit  \
# 0 1960-01-01             NA    NaN    a  percentage-of-active-population
# 1 1961-01-01             NA    NaN    a  percentage-of-active-population
# 2 1962-01-01             NA    NaN    a  percentage-of-active-population
# 3 1963-01-01             NA    NaN    a  percentage-of-active-population
# 4 1964-01-01             NA    NaN    a  percentage-of-active-population
#
#     geo Frequency                               Unit                   Country
# 0  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 1  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 2  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 3  ea19  Annually  (Percentage of active population)  Euro area (19 countries)
# 4  ea19  Annually  (Percentage of active population)  Euro area (19 countries)

# %% [markdown]
# ## Mix different frequencies on the same chart

# %%
multi_freq_df = fetch_series([
    "BEA/NIUnderlyingDetail-U001BC/S315-A",
    "BEA/NIUnderlyingDetail-U001BC/S315-Q",
    "BEA/NIUnderlyingDetail-U001BC/S315-M",
])

# %%
chart = Chart(multi_freq_df).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Transform time series

# %% [markdown]
# The `dbnomics` Python package can interact with the [Time Series Editor](https://editor.nomics.world/) to transform time series by applying filters to them. Available filters are listed on the [filters page](https://editor.nomics.world/filters).
#
# The Time Series Editor is usable via a web interface ([example with AMECO/ZUTN/EA19.1.0.0.0.ZUTN](https://editor.nomics.world/series?source=dbnomics&series_id=AMECO/ZUTN/EA19.1.0.0.0.ZUTN)) but you can call it directly from Python.
#
# You can chain many filters.
#
# Here is an example of how to proceed to interpolate two annual time series with a monthly frequency, using a spline interpolation:

# %%
filters = [
    {
        "code": "interpolate",
        "parameters": {"frequency": "monthly", "method": "spline"}
    }
]

# %%
df5 = fetch_series([
    'AMECO/ZUTN/EA19.1.0.0.0.ZUTN',
    'AMECO/ZUTN/DNK.1.0.0.0.ZUTN',
], filters=filters)
df5
# Out:
#     @frequency provider_code dataset_code  \
# 0       annual         AMECO         ZUTN
# 1       annual         AMECO         ZUTN
# 2       annual         AMECO         ZUTN
# 3       annual         AMECO         ZUTN
# 4       annual         AMECO         ZUTN
# ..         ...           ...          ...
# 788    monthly         AMECO         ZUTN
# 789    monthly         AMECO         ZUTN
# 790    monthly         AMECO         ZUTN
# 791    monthly         AMECO         ZUTN
# 792    monthly         AMECO         ZUTN
#
#                                           dataset_name  \
# 0    Unemployment rate: total :- Member States: def...
# 1    Unemployment rate: total :- Member States: def...
# 2    Unemployment rate: total :- Member States: def...
# 3    Unemployment rate: total :- Member States: def...
# 4    Unemployment rate: total :- Member States: def...
# ..                                                 ...
# 788  Unemployment rate: total :- Member States: def...
# 789  Unemployment rate: total :- Member States: def...
# 790  Unemployment rate: total :- Member States: def...
# 791  Unemployment rate: total :- Member States: def...
# 792  Unemployment rate: total :- Member States: def...
#
#                    series_code  \
# 0            EA19.1.0.0.0.ZUTN
# 1            EA19.1.0.0.0.ZUTN
# 2            EA19.1.0.0.0.ZUTN
# 3            EA19.1.0.0.0.ZUTN
# 4            EA19.1.0.0.0.ZUTN
# ..                         ...
# 788  DNK.1.0.0.0.ZUTN_filtered
# 789  DNK.1.0.0.0.ZUTN_filtered
# 790  DNK.1.0.0.0.ZUTN_filtered
# 791  DNK.1.0.0.0.ZUTN_filtered
# 792  DNK.1.0.0.0.ZUTN_filtered
#
#                                            series_name original_period  \
# 0    Annually – (Percentage of active population) –...            1960
# 1    Annually – (Percentage of active population) –...            1961
# 2    Annually – (Percentage of active population) –...            1962
# 3    Annually – (Percentage of active population) –...            1963
# 4    Annually – (Percentage of active population) –...            1964
# ..                                                 ...             ...
# 788  Annually – (Percentage of active population) –...         2025-09
# 789  Annually – (Percentage of active population) –...         2025-10
# 790  Annually – (Percentage of active population) –...         2025-11
# 791  Annually – (Percentage of active population) –...         2025-12
# 792  Annually – (Percentage of active population) –...         2026-01
#
#         period period_middle_day original_value     value  filtered freq  \
# 0   1960-01-01               NaN             NA       NaN     False    a
# 1   1961-01-01               NaN             NA       NaN     False    a
# 2   1962-01-01               NaN             NA       NaN     False    a
# 3   1963-01-01               NaN             NA       NaN     False    a
# 4   1964-01-01               NaN             NA       NaN     False    a
# ..         ...               ...            ...       ...       ...  ...
# 788 2025-09-01        2025-09-15       5.735982  5.735982      True  NaN
# 789 2025-10-01        2025-10-15       5.743284  5.743284      True  NaN
# 790 2025-11-01        2025-11-15       5.755988  5.755988      True  NaN
# 791 2025-12-01        2025-12-15       5.774693  5.774693      True  NaN
# 792 2026-01-01        2026-01-15            5.8  5.800000      True  NaN
#
#                                 unit   geo Frequency  \
# 0    percentage-of-active-population  ea19  Annually
# 1    percentage-of-active-population  ea19  Annually
# 2    percentage-of-active-population  ea19  Annually
# 3    percentage-of-active-population  ea19  Annually
# 4    percentage-of-active-population  ea19  Annually
# ..                               ...   ...       ...
# 788                              NaN   NaN       NaN
# 789                              NaN   NaN       NaN
# 790                              NaN   NaN       NaN
# 791                              NaN   NaN       NaN
# 792                              NaN   NaN       NaN
#
#                                   Unit                   Country
# 0    (Percentage of active population)  Euro area (19 countries)
# 1    (Percentage of active population)  Euro area (19 countries)
# 2    (Percentage of active population)  Euro area (19 countries)
# 3    (Percentage of active population)  Euro area (19 countries)
# 4    (Percentage of active population)  Euro area (19 countries)
# ..                                 ...                       ...
# 788                                NaN                       NaN
# 789                                NaN                       NaN
# 790                                NaN                       NaN
# 791                                NaN                       NaN
# 792                                NaN                       NaN
#
# [1720 rows x 18 columns]

# %% [markdown]
# The `DataFrame` columns change when filters are used:
#
# - `period_middle_day`: the middle day of `original_period` (can be useful when you compare graphically interpolated series and original ones)
# - `filtered` (`bool`): `True` if the series is filtered
# - `series_code`: same as before for original series, but the suffix `_filtered` is added for filtered series
# - `series_name`: same as before for original series, but the suffix ` (filtered)` is added for filtered series

# %%
chart = Chart(df5).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# alt.Chart(...)
