# %% [markdown]
# # [Estrarre una tabella](https://medium.com/geekculture/web-scraping-tables-in-python-using-beautiful-soup-8bbc31c5803e)
#
# https://www.ecommerceitalia.info/

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36"}

# %%
# Create an URL object
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/alimentare/'# Create object page
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/animali/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/assicurazioni/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/auto-e-moto/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/bambini-e-giocattoli/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/casa-e-arredamento/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/editoria/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/elettronica/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/farmacie/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/gioielli-e-orologi/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/marketplace/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/moda/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/salute-bellezza/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/scommesse-e-casino/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/sport/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/tempo-libero/'
#url = 'https://www.ecommerceitalia.info/e-commerce-ranking/settore/turismo/'
#url = 'https://ec.europa.eu/competition/elojade/isef/index.cfm?fuseaction=dsp_result&policy_area_id=1,2,3#'
# url = 'https://www.teleborsa.it/Quotazioni/Tassi/Forward' # Euribor FRA

url = 'https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=abruzzo&regione_estesa=Abruzzo'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

print('Classes of each table:')
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# Classes of each table:
# ['sele', 'table']

# %%
# tables = soup.find_all('table') # Creating list with all tables 
table = soup.find('table', class_='table') #  Looking for the table with the classes 'wikitable' and 'sortable'

# %%
header = []
rows = []
for i, row in enumerate(table.find_all('tr')):
    if i == 0:
        header = [el.text.strip() for el in row.find_all('th')]
    else:
        rows.append([el.text.strip() for el in row.find_all('td')])

# print(header)
for row in rows:
    print(row)
# Out:
# ['Comune: (172 comuni)', "*\nAlanno\nAlba Adriatica\nAltino\nAncarano\nArchi\nAri\nArsita\nAtessa\nAtri\nAvezzano\nBalsorano\nBarisciano\nBasciano\nBellante\nBisenti\nBucchianico\nBussi sul Tirino\nCagnano Amiterno\nCampli\nCampo di Giove\nCanosa Sannita\nCanzano\nCapestrano\nCapistrello\nCappelle sul Tavo\nCaramanico Terme\nCarsoli\nCasalbordino\nCasalincontrada\nCasoli\nCastel Castagna\nCastel di Sangro\nCastel Frentano\nCastellalto\nCastelli\nCastelvecchio Subequo\nCastiglione a Casauria\nCastiglione Messer Marino\nCastiglione Messer Raimondo\nCastilenti\nCatignano\nCelano\nCelenza sul Trigno\nCellino Attanasio\nCepagatti\nCerchio\nChieti\nCittÃ\xa0 Sant'Angelo\nCivitaquana\nCivitella Casanova\nCivitella del Tronto\nCivitella Roveto\nCollecorvino\nColledara\nCollelongo\nColonnella\nControguerra\nCorfinio\nCorropoli\nCrecchio\nCrognaleto\nCugnoli\nCupello\nElice\nFara Filiorum Petri\nFara San Martino\nFarindola\nFossacesia\nFrancavilla al Mare\nFrisa\nGioia dei Marsi\nGissi\nGiulia
# ...

# %% [markdown]
# ## altra prova
# https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=abruzzo&regione_estesa=Abruzzo&provincia=Chieti&comune=Chieti

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
prov = 'Messina'
url = "https://italia.indettaglio.it/ita/banche/sportelli_geo_out.html"
payload = {'regione': "Sicilia", 'regione_estesa': "Sicilia", "provincia": prov, 'comune':'*'}
response = requests.post(url, data=payload)
content = response.content
df_list = pd.read_html(content, header =0)
df = df_list[-1]
df.to_csv('D:/202403_'+prov+'.csv', index = False)
df
# Out:
#      Regione Provincia                     Comune  \
# 0    Sicilia   Messina                 Acquedolci
# 1    Sicilia   Messina                 Acquedolci
# 2    Sicilia   Messina                  Alì Terme
# 3    Sicilia   Messina             Alcara li Fusi
# 4    Sicilia   Messina  Barcellona Pozzo di Gotto
# ..       ...       ...                        ...
# 201  Sicilia   Messina                       Tusa
# 202  Sicilia   Messina                   Venetico
# 203  Sicilia   Messina        Villafranca Tirrena
# 204  Sicilia   Messina        Villafranca Tirrena
# 205  Sicilia   Messina        Villafranca Tirrena
#
#                             Indirizzo    Cap  \
# 0                     Corso Italia, 1  98070
# 1                 Corso Italia, 14/18  98070
# 2              Piazza Nino Prestia, 2  98021
# 3                    Via Garibaldi, 2  98070
# 4           Piazza San Sebastiano, 40  98051
# ..                                ...    ...
# ...

# %%
import glob
csv_files = glob.glob('D:/files/csv/abicab/202403_*.csv')
data = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)
# data.to_csv('AbiCab.csv', sep='|')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1542 entries, 0 to 1541
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Regione    1542 non-null   object
#  1   Provincia  1542 non-null   object
#  2   Comune     1542 non-null   object
#  3   Indirizzo  1542 non-null   object
#  4   Cap        1542 non-null   int64
#  5   Banca      1542 non-null   object
#  6   ABI        1542 non-null   int64
#  7   CAB        1542 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 96.5+ KB

# %%
data
# Out:
#       Regione  Provincia     Comune                     Indirizzo    Cap  \
# 0     Sicilia  Agrigento  Agrigento        Piazza Rosselli, 1/2/3  92100
# 1     Sicilia  Agrigento  Agrigento          Via Ugo la Malfa, 38  92100
# 2     Sicilia  Agrigento  Agrigento        Via Barone F. Celsa, 6  92100
# 3     Sicilia  Agrigento  Agrigento  Viale Leonardo Sciascia, 158  92100
# 4     Sicilia  Agrigento  Agrigento                 Via Atenea, 2  92100
# ...       ...        ...        ...                           ...    ...
# 1537  Sicilia    Trapani  Valderice                Via Erice, 2/4  91019
# 1538  Sicilia    Trapani  Valderice               Via Vespri, 269  91019
# 1539  Sicilia    Trapani  Valderice                Via Vespri, 97  91019
# 1540  Sicilia    Trapani  Valderice                 Via Vespri, 2  91019
# 1541  Sicilia    Trapani       Vita   Corso Giusepe Garibaldi, 57  91010
#
#                                                   Banca   ABI    CAB
# ...

# %%
data = pd.read_csv('AbiCab.csv', sep='|')

# %%
banca = data[['ABI','Banca']]

# %%
banca.drop_duplicates(subset=['ABI'], keep='first', inplace=True)

# %%
banca.sample(5)
# Out:
#        ABI                                              Banca
# 1     2008                     Unicredit, Societa' per Azioni
# 854   3102  Aletti & C. Banca di Investimento Mobiliare S....
# 326   3250                         Banca Euromobiliare S.P.A.
# 401   3058                                   Chebanca! S.P.A.
# 940  10643  Mps Capital Services Banca per le Imprese Spa ...

# %%
AbiCab = pd.merge(banca, data, how='left', left_on='ABI', right_on='ABI')

# %%
AbiCab
# Out:
#        ABI                                            Banca_x  Unnamed: 0  \
# 0     8954  Banca di Credito Cooperativo la Riscossa Di Re...           0
# 1     8954  Banca di Credito Cooperativo la Riscossa Di Re...           3
# 2     8954  Banca di Credito Cooperativo la Riscossa Di Re...           9
# 3     8954  Banca di Credito Cooperativo la Riscossa Di Re...          16
# 4     8954  Banca di Credito Cooperativo la Riscossa Di Re...          28
# ...    ...                                                ...         ...
# 1537  8712  Banca di Credito Cooperativo "Sen. Pietro Gram...        1328
# 1538  8712  Banca di Credito Cooperativo "Sen. Pietro Gram...        1342
# 1539  8712  Banca di Credito Cooperativo "Sen. Pietro Gram...        1374
# 1540  8712  Banca di Credito Cooperativo "Sen. Pietro Gram...        1401
# 1541  8712  Banca di Credito Cooperativo "Sen. Pietro Gram...        1402
#
#       Regione Provincia                  Comune  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', None)
banche = pd.pivot_table(AbiCab, index='Banca_x',columns='Provincia', aggfunc= {'ABI' : 'count'}, fill_value="").reset_index()

# %%
banche.iloc[0:17]

#banche.iloc[35:68]
# Out:
#                                                                                                      Banca_x  \
# Provincia
# 0          Aletti & C. Banca di Investimento Mobiliare S.P.A. (In Forma Abbreviata Banca Aletti & C. S.P.A.)
# 1                                                                     Allianz Bank Financial Advisors S.P.A.
# 2                                                                                       Artigiancassa S.P.A.
# 3                                          Banca Agricola Popolare di Ragusa Societa' Cooperativa Per Azioni
# 4                                                                                 Banca Carige Italia S.p.A.
# 5            Banca Carige S.P.A. - Cassa di Risparmio Di Genova e Imperia(in Forma Abbreviata Carige S.P.A.)
# 6                     Banca Don Rizzo - Credito Cooperativo della Sicilia Occidentale - Societa' Cooperativa
# ...

# %%
# print(banche.iloc[17:34].to_markdown())
banche.iloc[17:34]
# Out:
#                                                                                                  Banca_x  \
# Provincia
# 17                                           Banca Prossima S.P.A. (in Forma Abbreviata Prossima S.P.A.)
# 18                                        Banca San Francesco Credito Cooperativo - Societa' Cooperativa
# 19                                                                                  Banca Sella - S.P.A.
# 20                                       Banca Sviluppo Economico S.P.A. in Forma Abbreviata Base S.P.A.
# 21              Banca del Mezzogiorno - Mediocredito Centrale Spa (in Forma Abbreviata Bdm - Mcc S.P.A.)
# 22                Banca del Nisseno Credito Cooperativo Di Sommatino e Serradifalco Societa' Cooperativa
# 23         Banca di Credito Cooperativo "G. Toniolo" Di San Cataldo (Caltanissetta) Societa' Cooperativa
# 24                Banca di Credito Cooperativo "Sen. Pietro Grammatico" Di Paceco - Societa' Cooperativa
# ...

# %% [markdown]
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=abruzzo&regione_estesa=Abruzzo
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=basilicata&regione_estesa=Basilicata
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=calabria&regione_estesa=Calabria
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=campania&regione_estesa=Campania
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=molise&regione_estesa=Molise
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=puglia&regione_estesa=Puglia
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=sardegna&regione_estesa=Sardegna
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=sicilia&regione_estesa=Sicilia
#
#
# ### Sicilia
# - Agrigento
# - Caltanissetta
# - Catania
# - Enna
# - Messina
# - Palermo
# - Ragusa
# - Siracusa
# - Trapani
#
# ### Sardegna
# - Cagliari
# - Nuoro
# - Oristano
# - Sassari
# - Sud Sardegna
#
# ### Puglia
# - Barletta-Andria-Trani
# - Brindisi
# - Foggia
# - Lecce
# - Taranto
#
# ### Basilicata
# - Matera
# - Potenza
#
# ### Molise
# - Campobasso
# - Isernia
#
# ### Calabria
# - Catanzaro
# - Cosenza
# - Crotone
# - Reggio Calabria
# - Vibo Valentia
#
# ### Abruzzo
# - Chieti
# - L'Aquila
# - Pescara
# - Teramo
#
# ### Campania
# - Avellino
# - Benevento
# - Caserta
# - Napoli
# - Salerno

# %% [markdown]
# ### Resto d'Italia
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=emiliaromagna&regione_estesa=Emilia-Romagna
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=friuliveneziagiulia&regione_estesa=Friuli-Venezia%20Giulia
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=trentinoaltoadige&regione_estesa=Trentino-Alto%20Adige
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=liguria&regione_estesa=Liguria
# - https://italia.indettaglio.it/ita/banche/sportelli_geo.html?regione=piemonte&regione_estesa=Piemonte
#
#
# ### Valle d'Aosta
# Aosta
#
# ### Piemonte
# - Alessandria
# - Asti
# - Biella
# - Cuneo
# - Novara
# - Torino
# - Verbano-Cusio-Ossola
# - Vercelli
#
# ### Liguria
# - Genova
# - Imperia
# - La Spezia
# - Savona
#
# ### Lombardia
# - Bergamo
# - Brescia
# - Como
# - Cremona
# - Lecco
# - Lodi
# - Mantova
# - Milano
# - Monza e della Brianza
# - Pavia
# - Sondrio
# - Varese
#
# ### Trentino-Alto Adige
# - Bolzano
# - Trento
#
# ### Veneto
# - Belluno
# - Padova
# - Rovigo
# - Treviso
# - Venezia
# - Verona
# - Vicenza
#
# ### Friuli-Venezia-Giulia
# - Gorizia
# - Pordenone
# - Trieste
# - Udine
#
# ### Emilia-Romagna
# - Bologna
# - Ferrara
# - Forlì-Cesena
# - Modena
# - Parma
# - Piacenza
# - Ravenna
# - Reggio Emilia
# - Rimini
#
# ### Toscana
# - Arezzo
# - Firenze
# - Grosseto
# - Livorno
# - Lucca
# - Massa-Carrara
# - Pisa
# - Pistoia
# - Prato
# - Siena
#
# ### Marche
# - Ancona
# - Ascoli Piceno
# - Fermo
# - Macerata
# - Pesaro Urbino
#
# ### Umbria
# - Perugia
# - Terni
#
# ### Lazio
# - Frosinone
# - Latina
# - Rieti
# - Roma
# - Viterbo

# %% [markdown]
# ### backup

# %%
print(response.text)

# %%
content

# %%
# Parse the HTML response using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')
soup
