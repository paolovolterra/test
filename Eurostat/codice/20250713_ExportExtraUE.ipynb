# %% [markdown]
# 📦 Trump ha imposto dazi del 30% sull’export europeo. Ritorsioni o mano invisibile?
#
# Il dibattito si accende: l’Europa deve reagire con contromisure simmetriche o lasciar parlare il mercato?
#
# 💼 A prima vista, verrebbe da invocare dazi contro-dazi. Ma forse dovremmo tornare a Adam Smith. Se il libero scambio è ostacolato, sarà la mano invisibile del mercato – non i governi – a trovare nuove strade.
#
# 📉 Certo, ci vorranno tempi lunghi e costi reali:
#
#  riconversione logistica,
#  diversificazione dei mercati,
#  costruzione di nuove relazioni commerciali.
#
# 🌍 Ma i flussi commerciali tendono a riposizionarsi naturalmente. L’export europeo (soprattutto nei settori alimentare e industriale) potrebbe spostarsi verso Asia, Medio Oriente, Africa, dove la domanda è crescente e meno ostacolata da barriere politiche.
#
# 📊 Più che reagire di pancia, serve agire con strategia: supportare imprese e filiere nei processi di adattamento, senza cadere nella trappola del protezionismo reciproco.
#
# 🔍 La vera domanda non è "come rispondere a Trump", ma:
#
# > Come trasformare il vincolo in leva?

# %% [markdown]
# Esistono dataset ufficiali e dettagliati sull’export dell’UE verso i paesi extra-UE. Le fonti principali sono:
#
#
# ## 🌍 EUROSTAT – Commercio Estero (International Trade in Goods)
#
# ### 📦 Dataset consigliati:
#
# #### 1. [ext\_lt\_maineu](https://ec.europa.eu/eurostat/databrowser/view/ext_lt_maineu/default/table?lang=en)
#
# "EU trade by partner and product group"
#
#  Dati mensili/trimestrali
#  Export/import dell’UE verso singoli paesi extra-UE
#  Suddiviso per codici di prodotto (CPA/NACE)
#
# 📌 Variabili:
#
#  `FLOW`: export/import
#  `PARTNER`: paese destinatario (USA, Cina, EAU, ecc.)
#  `PRODUCT`: gruppo merceologico (es. C10 = alimentare)
#  `VALUE`: valore in milioni di euro
#  `GEO`: area reporter (UE o singolo Stato membro)
#
#
#
# #### 2. [ext\_lt\_intertrd](https://ec.europa.eu/eurostat/databrowser/view/ext_lt_intertrd/default/table?lang=en)
#
# "Extra-EU trade by main trading partners"
#
#  Dati aggregati mensili o annuali per partner
#  Focus su USA, Cina, Regno Unito, Svizzera, ecc.
#  Perfetto per grafici temporali e analisi impatto dazi
#
#
#
# #### 3. [ext\_lt\_intratrd](https://ec.europa.eu/eurostat/databrowser/view/ext_lt_intratrd/default/table?lang=en)
#
# Confronta intra-UE ed extra-UE trade
#
#  Utile per capire la dipendenza commerciale esterna
#  Include l’Italia e gli altri Stati membri
#
#
#
#
# ## 💡 Per analisi su Italia → Extra UE, puoi usare `GEO = IT` e `PARTNER != EU27_2020`.
#
# Oppure aggregare i dati per confrontare:
#
#  Export Italia vs Export UE
#  Export verso USA vs altri mercati (Cina, Medio Oriente, ecc.)
#  Effetti temporali post-dazi
