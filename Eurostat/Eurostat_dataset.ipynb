# %%
import pandas as pd

# Carica il file
df = pd.read_csv('https://ec.europa.eu/eurostat/api/dissemination/catalogue/toc/txt?lang=en', sep='\t')
df.insert(0, "row_id", range(1, len(df) + 1))
# Funzione per convertire in Period (mese o trimestre)
def parse_period(value):
    try:
        if 'Q' in str(value):
            return pd.Period(value, freq='Q')
        elif '-' in str(value):
            return pd.Period(value, freq='M')
        else:
            return pd.NaT
    except:
        return pd.NaT

# Applica direttamente ai valori testuali
df['data start'] = df['data start'].apply(parse_period)
df['data end'] = df['data end'].apply(parse_period)


# Conversione diretta delle due colonne
df['last update of data'] = pd.to_datetime(df['last update of data'], format='%d.%m.%Y', errors='coerce')
df['last table structure change'] = pd.to_datetime(df['last table structure change'], format='%d.%m.%Y', errors='coerce')
df.shape
# Out:
# (11859, 9)

# %%
df['type'].value_counts(dropna=False)
# Out:
# type
# dataset    8532
# folder     1862
# table      1465
# Name: count, dtype: int64

# %%
df[df['type'] == 'table'].head()
# Out:
#    row_id                                              title          code  \
# 4       5                   Current account - quarterly data   ei_bpm6ca_q
# 5       6                  Financial account - quarterly ...   ei_bpm6fa_q
# 6       7                     Current account - monthly data   ei_bpm6ca_m
# 7       8                   Financial account - monthly data   ei_bpm6fa_m
# 8       9                  International investment posit...  ei_bpm6iip_q
#
#     type last update of data last table structure change data start data end  \
# 4  table          2025-07-03                  2025-07-03     1991Q1   2025Q1
# 5  table          2025-07-03                  2025-07-03     1991Q1   2025Q1
# 6  table          2025-06-19                  2025-06-18    1991-01  2025-04
# 7  table          2025-06-19                  2025-06-18    1991-01  2025-04
# 8  table          2025-07-03                  2025-07-03     1992Q4   2025Q1
#
#      values  indent                                        title_clean
# 4  291800.0      16                   Current account - quarterly data
# 5   51657.0      16                 Financial account - quarterly data
# 6  240315.0      16                     Current account - monthly data
# 7   79123.0      16                   Financial account - monthly data
# 8   63632.0      16  International investment position - quarterly ...

# %%
# Conta indentazione: numero di spazi iniziali nel titolo
df['indent'] = df['title'].str.extract(r'^( *)')[0].str.len().fillna(0).astype(int)

# Rimuove spazi per il titolo leggibile
df['title_clean'] = df['title'].str.strip()

# %%
df.sample()
# Out:
#       row_id                                              title       code  \
# 9911    9912                  Seats held by women in nationa...  sdg_05_50
#
#          type last update of data last table structure change data start  \
# 9911  dataset          2025-04-11                  2025-04-11        NaT
#
#      data end  values  indent  \
# 9911      NaT  1551.0      16
#
#                                             title_clean
# 9911  Seats held by women in national parliaments an...

# %%
# Trova la riga che corrisponde a "na10"
row_index = df[df['code'] == 'na10'].index[0]
base_indent = df.at[row_index, 'indent']

# Seleziona righe sotto "na10" e con indent > base
sub_df = df.iloc[row_index + 1:]
sub_df = sub_df[sub_df['indent'] > base_indent]

# Fermati appena trovi un nodo dello stesso livello o superiore
stop_index = sub_df[sub_df['indent'] <= base_indent].index
if not stop_index.empty:
    sub_df = sub_df[:stop_index[0]]

# Filtro finale: solo le tabelle sotto 'na10'
tables_na10 = sub_df[sub_df['type'] == 'table'].copy()

print(tables_na10[['code', 'title_clean']])
# Out:
#                code                                        title_clean
# 1287       tipsen10    Net trade balance of energy products - % of GDP
# 1288       tipsna20    Gross fixed capital formation at current prices
# 1289       tec00115                      Real GDP growth rate - volume
# 1290       tipsna10  Gross domestic product (GDP) at market prices ...
# 1291       tipspd10              Private sector debt, non-consolidated
# 1292      cei_pc032  Generation of waste excluding major mineral wa...
# 1293       tec00001            Gross domestic product at market prices
# 1294       tec00013                          Compensation of employees
# 1295       tipsna30         Terms of trade by items - 5 years % change
# 1296       tec00010  Final consumption expenditure of general gover...
# 1297       tet00004          Imports of goods and services in % of GDP
# 1298       tipsna51  Final consumption expenditure of households an...
# 1299       tet00003          Exports of goods and services in % of GDP
# 1300       tec00011        Gross fixed capital formation (investments)
# 1301       tipslm13  Compensation of employees - annual data, milli...
# 1302       tipsex13                     Export market shares in volume
# 1303       tec00110            Goods and services, imports and exports
# 1304       tipspc10       Private sector credit flow, non-consolidated
# 1305       tec00009  Final consumption expenditure of households an...
# 1310       tec00001            Gross domestic product at market prices
# 1311      sdg_08_10                                Real GDP per capita
# 1312       tec00115                      Real GDP growth rate - volume
# 1313       tipsna40                                Real GDP per capita
# 1319       tec00134  Final consumption expenditure of households, b...
# 1322       tipsna50   Residential construction - annual data, % of GDP
# 1328       tipsho50                     Building permits - annual data
# 1329       tesem040                          Overall employment growth
# 1330      sdg_16_30  General government total expenditure on law co...
# 1332       tipsna62          Employees, domestic concept - annual data
# 1333       tipsna60         Employment, domestic concept - annual data
# 1334       tec00112               Employment, domestic concept - Total
# 1350       tgs00026  Disposable income of private households by NUT...
# 1351       tgs00036  Primary income of private households by NUTS 2...
# 1355       tec00116  Nominal labour productivity per person employe...
# 1356       tipslm10           Nominal unit labour cost per hour worked
# 1357       tesem170                    Nominal unit labour cost growth
# 1358       tipsna70  Labour productivity per hour worked - annual data
# 1359       tesem160  Labour productivity per person employed and ho...
# 1360       tipslm20  Nominal unit labour cost per hour worked - ann...
# 1371       tipsho41  Final consumption expenditure of households an...
# 1372       teina110                                       GDP deflator
# 1373       teina030  Government final consumption expenditure, curr...
# 1374       teina041             Gross fixed capital formation, volumes
# 1375       tipslm14  Compensation of employees - quarterly data, mi...
# 1376       teina040      Gross fixed capital formation, current prices
# 1377       tipsna15  Gross domestic product (GDP) at market prices ...
# 1378       teina031  Government final consumption expenditure, volumes
# 1379       teina011                    Gross domestic product, volumes
# 1380       teina010             Gross domestic product, current prices
# 1381       teina020  Final consumption expenditure of households an...
# 1382       teina021  Final consumption expenditure of households an...
# 1383       teina050  External balance of goods and services, curren...
# 1385    teina430_r2       Gross value added - NACE Rev. 2: K - volumes
# 1386    teina420_r2  Gross value added - NACE Rev. 2: G-I - current...
# 1387    teina436_r2  Gross value added - NACE Rev. 2: M_N - current...
# 1388    teina404_r2  Gross value added - NACE Rev. 2: A - current p...
# 1389    teina406_r2       Gross value added - NACE Rev. 2: A - volumes
# 1390    teina418_r2       Gross value added - NACE Rev. 2: F - volumes
# 1391    teina402_r2   Gross value added - NACE Rev. 2: TOTAL - volumes
# 1392    teina410_r2     Gross value added - NACE Rev. 2: B-E - volumes
# 1393    teina412_r2  Gross value added - NACE Rev. 2: C - current p...
# 1394    teina400_r2  Gross value added - NACE Rev. 2: TOTAL - curre...
# 1395    teina446_r2     Gross value added - NACE Rev. 2: R-U - volumes
# 1396    teina438_r2     Gross value added - NACE Rev. 2: M_N - volumes
# 1397    teina414_r2       Gross value added - NACE Rev. 2: C - volumes
# 1398    teina426_r2       Gross value added - NACE Rev. 2: J - volumes
# 1399    teina428_r2  Gross value added - NACE Rev. 2: K - current p...
# 1400    teina442_r2     Gross value added - NACE Rev. 2: O-Q - volumes
# 1401    teina416_r2  Gross value added - NACE Rev. 2: F - current p...
# 1402    teina075_r2            Compensation of employees - NACE Rev. 2
# 1403    teina432_r2  Gross value added - NACE Rev. 2: L - current p...
# 1404    teina408_r2  Gross value added - NACE Rev. 2: B-E - current...
# 1405    teina422_r2     Gross value added - NACE Rev. 2: G-I - volumes
# 1406    teina440_r2  Gross value added - NACE Rev. 2: O-Q - current...
# 1407    teina434_r2       Gross value added - NACE Rev. 2: L - volumes
# 1408    teina444_r2  Gross value added - NACE Rev. 2: R-U - current...
# 1409    teina424_r2  Gross value added - NACE Rev. 2: J - current p...
# 1411       teina023  Household final consumption expenditures by du...
# 1412       teina022  Household final consumption expenditures by du...
# 1418       tipsna61  Employment, domestic concept - quarterly data,...
# 1419       tec00109        Employment by NACE Rev.2 - thousand persons
# 1420       teina310  Employment by NACE Rev.2 - percentage change Q...
# 1421       teina306  Employment by NACE Rev.2 - percentage change Q...
# 1422       tec00108  Employment by NACE Rev.2 - percentage change Q...
# 1423       teina305  Employment by NACE Rev.2 - percentage change Q...
# 1426       tipslm40  Nominal unit labour cost (NULC) per hour worke...
# 1427       tipsna71  Real labour productivity per person employed p...
# 1429       teina043  Gross fixed capital formation by asset (AN_F6)...
# 1430       teina042  Gross fixed capital formation by asset (AN_F6)...
# 1493       tec00113  Adjusted gross disposable income of households...
# 1496       tipspd35  Non-financial corporations debt excluding fore...
# 1497       tipspd30  Non-financial corporations debt, consolidated ...
# 1498       tipspd40  Household including non-profit institutions se...
# 1500       tipspc30  Non-financial corporations excluding foreign d...
# 1501       tipspc40  Household including non-profit institutions se...
# 1506       tec00131                              Household saving rate
# 1507       tec00132                Investment by institutional sectors
# 1508       tec00104           Gross debt-to-income ratio of households
# 1543       tec00021                   Total general government revenue
# 1544       tec00023               Total general government expenditure
# 1563       tec00127                 General government deficit/surplus
# 1588       tec00033  ECU/EUR exchange rates versus national currencies
# 1658       tec00118                              HICP - inflation rate
# 1659       tec00027          HICP - all items - annual average indices
# 1660       tipscp10           Core inflation differential vis-à-vis EA
# 1669    prc_fsc_idx                         Food price monitoring tool
# 1689       tec00114                              GDP per capita in PPS
# 1690       tec00120                           Comparative price levels
# 1692       tec00121  Price and volume convergence between EU Member...
# 1723       tec00039  Current account transactions - goods: credits,...
# 1724       tec00041  Current account transactions - primary income:...
# 1725       tec00042  Current account transactions - secondary incom...
# 1726       tec00038  Current account transactions - credits, debits...
# 1727       tec00040  Current account transactions - services: credi...
# 1731       tec00041  Current account transactions - primary income:...
# 1732       tec00039  Current account transactions - goods: credits,...
# 1733       tec00042  Current account transactions - secondary incom...
# 1734       tec00038  Current account transactions - credits, debits...
# 1735       tec00040  Current account transactions - services: credi...
# 1748       tec00106                     Outward FDI stocks in % of GDP
# 1749       tec00105                      Inward FDI stocks in % of GDP
# 1750       tec00107            FDI flows intensity, market integration
# 1941       tps00001                            Population on 1 January
# 1942       tps00204                   Live births and crude birth rate
# 1943       tgs00027  Total population, Candidate countries and pote...
# 1944       eq_fer05                                        Live births
# 1945       tps00029                        Deaths and crude death rate
# 1946       tps00019  Population change - crude rates of total chang...
# 1947       eq_mor06                                      Deaths by sex
# 1948       tps00005  Population as a percentage of EU27 (from 2020)...
# 1950       tgs00099  Population change by NUTS 2 region - Crude rat...
# 1952       tps00028          Proportion of population aged 65 and over
# 1953       eq_pop04                                  Median age by sex
# 1954       tps00010                            Population by age group
# 1955       eq_pop03         Population structure by detailed age group
# 1956       eq_pop02                        Population structure by sex
# 1957       tps00198                           Old-age-dependency ratio
# 1961       tps00003                                 Population density
# 1962       tgs00024                Population density by NUTS 2 region
# 1972       tps00157  Population without the citizenship of the repo...
# 1974       tps00178                            Foreign-born population
# 1975   yth_demo_060  Youth population on 1 January by sex, age and ...
# 1986       tgs00096           Population on 1 January by NUTS 2 region
# 1992       tps00017  Mean age of women at childbirth and at birth o...
# 1993       tps00199                               Total fertility rate
# 2013       tgs00100              Total fertility rate by NUTS 2 region
# 2021       tps00205                    Life expectancy at birth by sex
# 2031       tps00027                              Infant mortality rate
# 2039       tgs00101  Life expectancy at birth by sex and NUTS 2 region
# 2061       tps00206                                Crude marriage rate
# 2062       tps00014                  Mean age at first marriage by sex
# 2071       tps00216                                 Crude divorce rate
# 2078       tps00002                             Population projections
# 2084       tps00200                 Projected old-age dependency ratio
# 2114       tps00176                                        Immigration
# 2116   yth_demo_070  Young immigrants by sex, age and country of birth
# 2130       tps00177                                         Emigration
# 2132   yth_demo_080   Young emigrants by sex, age and country of birth
# 2139       tps00024                         Acquisition of citizenship
# 2170       tps00194  Asylum applicants considered to be unaccompani...
# 2182       tps00191  Asylum applicants by type - annual aggregated ...
# 2184       tps00189           Asylum applicants by type - monthly data
# 2186       tps00190  Persons subject of asylum applications pending...
# 2205       tps00192  First instance decisions on asylum application...
# 2210       tps00193  Final decisions on asylum applications by type...
# 2213       tps00195                    Resettled persons - annual data
# 2265       tps00170                            First permits by reason
# 2272       tps00171  All valid permits by reason on 31 December of ...
# 2307       tps00208                    Life expectancy at birth by sex
# 2308       tps00150                 Healthy life years at birth by sex
# 2488       tps00214                Long-term care (health) expenditure
# 2489       tps00207                      Total health care expenditure
# 2509       tgs00064       Available beds in hospitals by NUTS 2 region
# 2514       tps00046                                      Hospital beds
# 2519       tps00044                              Practising physicians
# 2520       tps00045                                Practising dentists
# 2521       tps00167                                Licensed physicians
# 2526       tgs00064       Available beds in hospitals by NUTS 2 region
# 2538       tps00048                          Discharges from hospitals
# 2671       tps00134  Death due to diseases of the nervous system, b...
# 2672       tps00165           Death due to transport accidents, by sex
# 2673       tps00149              Death due to drugs dependence, by sex
# 2674       tps00146             Death due to homicide, assault, by sex
# 2675       tps00122                       Death due to suicide, by sex
# 2676       tps00152                            Causes of death, by sex
# 2677       tps00131         Death due to chronic liver disease, by sex
# 2678       tps00143            Death due to AIDS (HIV-disease), by sex
# 2679       tps00140               Death due to alcoholic abuse, by sex
# 2680       tps00125                     Death due to accidents, by sex
# 2681       tps00137             Death due to diabetes mellitus, by sex
# 2682       tps00119  Death due to other ischaemic heart diseases, b...
# 2683       tps00116                        Death due to cancer, by sex
# 2684       tps00128                     Death due to pneumonia, by sex
# 2686       tps00202                    Suicide death rate by age group
# 2692       tgs00061  Death due to transport accidents by NUTS 2 region
# 2693       tgs00058               Death due to cancer by NUTS 2 region
# 2694       tgs00059  Death due to ischaemic heart diseases by NUTS ...
# 2695       tgs00057               All causes of death by NUTS 2 region
# 2696       tgs00060            Death due to accidents by NUTS 2 region
# 2718      sdg_11_52  Premature deaths due to exposure to fine parti...
# 2950    dsb_sprex01  Social protection expenditure on disability by...
# 2951    dsb_sprex02  Social protection expenditure on disability by...
# 2952    dsb_sprex03  Social protection expenditure on disability by...
# 2954    dsb_sprpb01  Beneficiaries of disability pensions by pensio...
# 2955    dsb_sprpb02        Beneficiaries of disability pensions by sex
# 2958    tepsr_sp200  Disability employment gap by level of activity...
# 2998    dsb_ictiu01  Persons using the internet in the past 12 mont...
# 2999    dsb_ictiu02  Persons regularly using the internet by level ...
# 3000    dsb_ictiu03  Persons using the internet for learning activi...
# 3001    dsb_ictiu04  Persons using the internet for telephoning or ...
# 3002    dsb_ictiu05  Persons using the internet for participating i...
# 3003    dsb_ictiu06  Persons using the internet for finding informa...
# 3004    dsb_ictiu07  Persons using the internet for internet bankin...
# 3005    dsb_ictiu08  Persons using the internet for seeking health ...
# 3006    dsb_ictiu09  Persons using the internet for making an appoi...
# 3008    dsb_icteg01  Persons using the internet for interaction wit...
# 3009    dsb_icteg02  Persons using the internet to request official...
# 3010    dsb_icteg03  Persons using the internet for making an appoi...
# 3011    dsb_icteg04  Persons using a website or app of public autho...
# 3012    dsb_icteg05  Persons having no issue when using a website o...
# 3221   yth_educ_060  Participation rate in non-formal education and...
# 3471       tps00217  Female tertiary education graduates in STEM ed...
# 3479   yth_demo_040  Young people by educational attainment level, ...
# 3491       tps00215   Exposure of VET graduates to work-based learning
# 3500   yth_educ_020  Population aged 30-34 with tertiary educationa...
# 3501   yth_educ_030  Young people aged 20-24 with at least upper se...
# 3502       tps00065  At least upper secondary educational attainmen...
# 3503       tps00186  At least upper secondary educational attainmen...
# 3504       tps00197  At most lower secondary educational attainment...
# 3506       tgs00109  Tertiary educational attainment, age group 25-...
# 3507       tgs00105  Tertiary educational attainment, age group 25-...
# 3512       tps00066  Unemployment rates of the population aged 25-6...
# 3545       tgs00106  Early leavers from education and training by s...
# 3550       tps00053               Employment rates of recent graduates
# 3699      tipslm100                                    Employment rate
# 3704       tps00073  Employees with a contract of limited duration ...
# 3705       tps00159                 Persons employed part-time - Total
# 3723       tps00203                            Total unemployment rate
# 3872        tqoe4a3  Employed persons being self-employed without e...
# 3875        tqoe3a5   Employed persons having more than one job by sex
# 3883        tqoe1c2  Employed women being in managerial positions b...
# 3912        tqoe4a3  Employed persons being self-employed without e...
# 3951        tqoe3a5   Employed persons having more than one job by sex
# 3964       tps00071      Hours worked per week of full-time employment
# 3974       tps00066  Unemployment rates of the population aged 25-6...
# 4034       tps00182                          Jobless households by sex
# 4035       tps00181                      Jobless households - children
# 4064       tgs00007  Employment rate of the age group 15-64 by NUTS...
# 4070       tgs00010                 Unemployment rate by NUTS 2 region
# 4496        tqoe3b4     Employees with a flexible work schedule by sex
# 4602        tqoe3b4     Employees with a flexible work schedule by sex
# 4695       tps00172  Job vacancies in number and % - NACE Rev. 2, B...
# 5093       tps00155                                      Minimum wages
# 5122       tps00173             Labour costs annual data - NACE Rev. 2
# 5210       tgs00107  People at risk of poverty or social exclusion ...
# 5217    tepsr_lm412  Children (aged less than 18) at risk of povert...
# 5218      sdg_01_10     Persons at risk of poverty or social exclusion
# 5241       ilc_pns4  Inequality of income distribution S80/S20 inco...
# 5253       tessi191  Gini coefficient of equivalised disposable inc...
# 5260       ilc_pns8  Dispersion around the at-risk-of-poverty thres...
# 5261       ilc_pns1  At-risk-of-poverty rate of older people, by ag...
# 5262       tps00184  At-risk-of-poverty rate after social transfers...
# 5263       ilc_pnp1  At-risk-of-poverty rate of older people by sex...
# 5266       ilc_pns6  At-risk-of-poverty rate for pensioners - EU-SI...
# 5271       tps00151  At-risk-of-poverty-rate, by highest level of e...
# 5273       ilc_pns7  At-risk-of-poverty rate of older people by ten...
# 5279       ilc_pns5  Relative median at-risk-of-poverty gap of elde...
# 5291       tgs00103           At-risk-of-poverty rate by NUTS 2 region
# 5303       ilc_pnp1  At-risk-of-poverty rate of older people by sex...
# 5304       ilc_pns1  At-risk-of-poverty rate of older people, by ag...
# 5305       ilc_pns6  At-risk-of-poverty rate for pensioners - EU-SI...
# 5306       ilc_pns7  At-risk-of-poverty rate of older people by ten...
# 5307       ilc_pns8  Dispersion around the at-risk-of-poverty thres...
# 5318       ilc_pns4  Inequality of income distribution S80/S20 inco...
# 5319       ilc_pns5  Relative median at-risk-of-poverty gap of elde...
# 5407       tgs00108  People living in households with very low work...
# 5453       tps00185        Formal child care by duration and age group
# 5505       tespm030        Severe material and social deprivation rate
# 5516       tessi080  Material Deprivation rate by sex - EU-SILC survey
# 5517       tessi082  Material Deprivation rate by age group - EU-SI...
# 5519       tessi150     Depth of material deprivation - EU-SILC survey
# 5535       tgs00104  Severe material deprivation rate by NUTS 2 region
# 5851      sdg_05_11  Physical and sexual violence to women by age g...
# 5967       tps00101           Expenditure on social protection by type
# 5968       tps00099  Expenditure on social protection per inhabitan...
# 5969       tps00098  Expenditure on social protection as percentage...
# 5970       tps00100  Expenditure on social protection per inhabitan...
# 5972       tps00106  Social benefits by function - % of total benefits
# 5973       tps00107   Social benefits by function - PPS per inhabitant
# 5975       tps00103       Expenditure on pensions as percentage of GDP
# 5979    dsb_sprex03  Social protection expenditure on disability by...
# 5980    dsb_sprex02  Social protection expenditure on disability by...
# 5981    dsb_sprex01  Social protection expenditure on disability by...
# 5992       tps00083                    Net social benefits by function
# 5993       tps00082          Social benefits by function - million EUR
# 5998       tps00108  Social protection receipts by type as percenta...
# 6004    dsb_sprpb01  Beneficiaries of disability pensions by pensio...
# 6005    dsb_sprpb02        Beneficiaries of disability pensions by sex
# 6169      sdg_16_70      Victims of trafficking in human beings by sex
# 6211    prc_fsc_idx                         Food price monitoring tool
# 6243       tipsho50                     Building permits - annual data
# 6256       teiis715                             Production in services
# 6257      ei_issp_m  Production in services index by NACE Rev.2 act...
# 6258     ei_isspr_m  Production in services growth rates by NACE Re...
# 6260      ei_issp_q  Production in services index by NACE Rev.2 act...
# 6653       tin00172  Percentage change (compared to corresponding p...
# 6654       tin00171  Nights spent at tourist accommodation establis...
# 6657       tin00173  Net occupancy rate of bed-places and bedrooms ...
# 6662       tin00175  Nights spent at tourist accommodation establis...
# 6663       tin00177  Nights spent at tourist accommodation establis...
# 6665       tgs00111  Nights spent at tourist accommodation establis...
# 6667       tin00176  Nights spent at tourist accommodation establis...
# 6676       tin00174  Arrivals of residents/non-residents at tourist...
# 6681       tin00180  Net occupancy rate of bed-places and bedrooms ...
# 6685       tin00181            Number of establishments and bed-places
# 6686       tin00182             Number of bed-places by NACE Rev.2 (I)
# 6688       tgs00112  Number of establishments and bed-places by NUT...
# 6723       tin00187  Persons participating in tourism for personal ...
# 6734       tin00186  Participation in tourism for personal purposes...
# 6735       tin00185  Persons participating in tourism for personal ...
# 6739       tin00188                                   Trips by purpose
# 6741       tin00189                      Trips by duration of the trip
# 6758       tin00190  Trips by detailed country/world region of main...
# 6762       tin00191                            Nights spent by purpose
# 6764       tin00192               Nights spent by duration of the trip
# 6781       tin00193  Nights spent by detailed country/world region ...
# 6802       tin00194             Expenditure by category of expenditure
# 6803       tin00196                      Average expenditure per night
# 6804       tin00195                       Average expenditure per trip
# 6840          tai09                            Livestock density index
# 6917       tag00001         Agricultural holdings by agricultural area
# 6921       tag00125            Agricultural holdings by age of manager
# 6923       tag00123  Agricultural holdings by economic size of the ...
# 6931       tag00124               Agricultural holdings with livestock
# 6941       tag00007                     Agricultural holdings by crops
# 6982       tag00020                                  Farm labour force
# 6990       tag00029             Agricultural holdings by age of holder
# 7103       tag00102  Output of the agricultural industry - basic an...
# 7104       tag00056  Gross value added of the agricultural industry...
# 7105       tag00054            Crop output - basic and producer prices
# 7106       tag00055          Animal output - basic and producer prices
# 7112       tag00057  Indicator A of the income from agricultural ac...
# 7126       tag00062                            Selling prices of maize
# 7127       tag00060                           Selling prices of barley
# 7128       tag00064          Selling prices of sugar beet (unit value)
# 7129       tag00063               Selling prices of main crop potatoes
# 7130       tag00059                       Selling prices of soft wheat
# 7131       tag00061                             Selling prices of oats
# 7133       tag00068       Selling prices of chickens (live 1st choice)
# 7134       tag00071                       Selling prices of fresh eggs
# 7135       tag00069                            Selling prices of sheep
# 7136       tag00067                          Selling prices of piglets
# 7137       tag00066                     Selling prices of pigs (light)
# 7138       tag00070                   Selling prices of raw cow's milk
# 7139       tag00065                           Selling prices of calves
# 7170       tag00052  Purchase price indices, total means of agricul...
# 7174       tag00050  Producer price indices, animals and animal pro...
# 7175       tag00048              Producer price indices, crop products
# 7176       tag00046  Producer price indices, total agricultural pro...
# 7196       tag00025           Utilised agricultural area by categories
# 7197          tai04  Final energy consumption by agriculture and fo...
# 7198       tag00115          Fresh vegetables and strawberries by area
# 7199       tag00120      Permanent crops for human consumption by area
# 7200       tag00047   Wheat and spelt by area, production and humidity
# 7201       tag00100  Rape, turnip rape, sunflower seeds and soya by...
# 7202       tag00103  Root crops and plants harvested green from ara...
# 7203       tag00101       Green maize by area, production and humidity
# 7204       tag00051            Barley by area, production and humidity
# 7205       tag00094  Dry pulses and protein crops for the productio...
# 7206       tag00053  Oats and spring cereal mixtures by area, produ...
# 7207       tag00027  Cereals for the production of grain (including...
# 7208       tag00121                               Grapes by production
# 7209       tag00093  Grain maize and corn-cob-mix by area, producti...
# 7210       tag00122                               Olives by production
# 7211       tag00049  Rye and winter cereal mixtures by area, produc...
# 7242       tag00038                               Production of butter
# 7243       tag00040                               Production of cheese
# 7244       tag00037                           Collection of cow's milk
# 7245       tag00039                          Production of milk powder
# 7249       tag00041                        Production of milk on farms
# 7251       tgs00046  Production of cow's milk on farms by NUTS 2 re...
# 7256       tag00045  Production of sheepmeat and goat meat in slaug...
# 7257       tag00044       Production of bovine meat in slaughterhouses
# 7258       tag00043      Production of poultry meat in slaughterhouses
# 7259       tag00042           Production of pigmeat in slaughterhouses
# 7267       tag00016                           Number of bovine animals
# 7268       tag00014                               Number of dairy cows
# 7272       tag00017                                    Number of sheep
# 7274       tag00018                                     Number of pigs
# 7276       tgs00045                Animal populations by NUTS 2 region
# 7352          tai02           Sales of pesticides by type of pesticide
# 7361          tai05  Share of main land types in utilised agricultu...
# 7363          tai03  Share of irrigable and irrigated areas in util...
# 7365          tai06  Share of main livestock types in total livesto...
# 7440       tag00076                      Catches in all fishing region
# 7454       tag00075         Aquaculture production in tonnes and value
# 7489       tag00116                   Fishing Fleet, Number of Vessels
# 7490       tag00083                       Fishing fleet, total tonnage
# 7497       tet00071  Trade in goods, by main world traders - EU27 (...
# 7499       tet00037           Share of trade with the EU27 (from 2020)
# 7500       tet00001         Trade volume indices, by reporting country
# 7501       tet00028     Trade unit value indices, by reporting country
# 7502       tet00002  International trade, by reporting country, tot...
# 7503       tipsen10    Net trade balance of energy products - % of GDP
# 7505       tet00038  International trade of EFTA and enlargement co...
# 7507       tet00066     Extra-euro area (EA20) trade, by product group
# 7508       tet00065  Extra-euro area (EA20) trade, by main partners...
# 7511       tet00013     Extra-EU27 (from 2020) trade, by product group
# 7512       tet00011  Intra-EU27 (from 2020) trade, by Member State,...
# 7513       tet00012  Extra-EU27 (from 2020) trade, by Member State,...
# 7524       teiet050  Exports of goods - chemicals and related products
# 7525       teiet140  Imports of goods - mineral fuels, lubricants a...
# 7526       teiet210     Balance of trade - EU and euro area aggregates
# 7527       teiet160     Imports of goods - other manufactured products
# 7528       teiet060     Exports of goods - other manufactured products
# 7529       teiet040  Exports of goods - mineral fuels, lubricants a...
# 7530       teiet030                   Exports of goods - raw materials
# 7531       teiet130                   Imports of goods - raw materials
# 7532       teiet010                           Exports of goods - total
# 7533       teiet310                              Unit value of imports
# 7534       teiet020        Exports of goods - food, drinks and tobacco
# 7535       teiet150  Imports of goods - chemicals and related products
# 7536       teiet120        Imports of goods - food, drinks and tobacco
# 7537       teiet070  Exports of goods - machinery and transport equ...
# 7538       teiet300                              Unit value of exports
# 7539       teiet170  Imports of goods - machinery and transport equ...
# 7540       teiet110                           Imports of goods - total
# 7543      ei_etea_m       Euro area international trade - monthly data
# 7544       teiet215                                   Balance of trade
# 7546      ei_etea_m       Euro area international trade - monthly data
# 7562       tet00067  Extra-EU imports by Member State, shares by in...
# 7563       tet00068  Extra-EU exports by Member State, shares by in...
# 7590       ttr00016  Air transport of passengers by country and typ...
# 7591       ttr00012  Air transport of passengers by country (yearly...
# 7593       ttr00017  Air transport of passengers by airport and typ...
# 7647       ttr00011    Air transport of goods by country (yearly data)
# 7711       tgs00077       Air transport of passengers by NUTS 2 region
# 7713       tgs00078          Air transport of freight by NUTS 2 region
# 7741       ttr00007                Goods transport by inland waterways
# 7898       ttr00009                             Sea transport of goods
# 7903       tgs00075  Maritime transport of passengers by NUTS 2 region
# 7905       tgs00076     Maritime transport of freight by NUTS 2 region
# 7927       ttr00003                      Total length of railway lines
# 7953       ttr00015                       Rail transport of passengers
# 7973       ttr00006                            Goods transport by rail
# 8123       ttr00002                          Total length of motorways
# 8212       ttr00005                            Goods transport by road
# 8295       tgs00113                      Rail network by NUTS 2 region
# 8296       tgs00114                 Motorways network by NUTS 2 region
# 8301       tgs00075  Maritime transport of passengers by NUTS 2 region
# 8303       tgs00076     Maritime transport of freight by NUTS 2 region
# 8305       tgs00077       Air transport of passengers by NUTS 2 region
# 8307       tgs00078          Air transport of freight by NUTS 2 region
# 8315      sdg_09_60  Share of rail and inland waterways in inland f...
# 8317      sdg_09_50  Share of buses and trains in inland passenger ...
# 8329       ttr00001      Volume of passenger transport relative to GDP
# 8344          tai08          Greenhouse gas emissions from agriculture
# 8349       ten00137           Domestic material consumption per capita
# 8355     cei_gsr030                         Material import dependency
# 8366       ten00141                         Environmental tax revenues
# 8369       ten00139                                       Energy taxes
# 8374       ten00136  Environmental protection investments of total ...
# 8386       ten00135   National expenditure on environmental protection
# 8396       ten00136  Environmental protection investments of total ...
# 8408       ten00135   National expenditure on environmental protection
# 8429      cei_pc035                                         Food waste
# 8432       ten00062                 Recovery rates for packaging waste
# 8434       ten00063                Recycling rates for packaging waste
# 8447       ten00001          Water resources: long-term annual average
# 8459       ten00001          Water resources: long-term annual average
# 8481      sdg_12_21                     Raw material consumption (RMC)
# 8482      cei_pc020                                 Material footprint
# 8494       ten00124                 Final energy consumption by sector
# 8495       ten00129  Final energy consumption in industry by type o...
# 8496       ten00123                Final energy consumption by product
# 8497       ten00121                  Gross available energy by product
# 8498       ten00122                     Total energy supply by product
# 8499          tai04  Final energy consumption by agriculture and fo...
# 8501       ten00127  Final energy consumption in road transport by ...
# 8502       ten00125  Final energy consumption in households by type...
# 8503       ten00126  Final energy consumption in transport by type ...
# 8531      sdg_07_11                           Final energy consumption
# 8532      sdg_07_10                         Primary energy consumption
# 8537      sdg_07_50               Energy import dependency by products
# 8630       ten00118                         Gas prices by type of user
# 8632       ten00118                         Gas prices by type of user
# 8634       ten00117                 Electricity prices by type of user
# 8636       ten00117                 Electricity prices by type of user
# 8654       ten00119  Market share of the largest generator in the e...
# 8665       tsc00001  Research and development expenditure by sector...
# 8673       tgs00042  Intramural R&D expenditure (GERD) by NUTS 2 re...
# 8684       tsc00003  Total researchers by sector of performance - h...
# 8685       tsc00004  Total researchers by sector of performance - f...
# 8687       tsc00002  Research and development personnel by sector o...
# 8693       tgs00043        Researchers in all sectors by NUTS 2 region
# 8695       tsc00006          Share of women researchers in all sectors
# 8696       tsc00005  Share of women researchers by sector of perfor...
# 8703       tsc00008  Share of government allocations for R&D (GBARD...
# 9084       tin00140                                  High-tech exports
# 9090       tsc00011  Employment in high- and medium-high technology...
# 9102       tgs00039   Employment in high-tech sectors by NUTS 2 region
# 9132       tsc00025   Human resources in science and technology (HRST)
# 9140       tgs00038  Human resources in science and technology (HRS...
# 9181      sdg_09_40  Patent applications to the European Patent Off...
# 9186       tin00134              Level of internet access - households
# 9191       tin00092          Individuals frequently using the internet
# 9192       tin00091           Individuals regularly using the internet
# 9193    dsb_ictiu02  Persons regularly using the internet by level ...
# 9196    dsb_ictiu04  Persons using the internet for telephoning or ...
# 9197    dsb_ictiu03  Persons using the internet for learning activi...
# 9198       tin00101  Individuals using the internet for seeking hea...
# 9199       tin00129  Individuals using the internet for taking part...
# 9200       tin00102  Individuals using the internet for looking for...
# 9201    dsb_ictiu06  Persons using the internet for finding informa...
# 9202    dsb_ictiu07  Persons using the internet for internet bankin...
# 9203    dsb_ictiu05  Persons using the internet for participating i...
# 9204       tin00127  Individuals using the internet for participati...
# 9205    dsb_ictiu08  Persons using the internet for seeking health ...
# 9206       tin00098  Individuals using the internet for selling goo...
# 9207       tin00095  Individuals using the internet for finding inf...
# 9208       tin00103  Individuals using the internet for doing an on...
# 9209    dsb_ictiu09  Persons using the internet for making an appoi...
# 9210       tin00094  Individuals using the internet for sending/rec...
# 9211       tin00099  Individuals using the internet for internet ba...
# 9216       tin00096  Individuals using the internet for buying good...
# 9229    dsb_icteg04  Persons using a website or app of public autho...
# 9230    dsb_icteg02  Persons using the internet to request official...
# 9231    dsb_icteg01  Persons using the internet for interaction wit...
# 9232    dsb_icteg03  Persons using the internet for making an appoi...
# 9235    dsb_icteg05  Persons having no issue when using a website o...
# 9247       tgs00047  Households that have internet access at home b...
# 9250       tgs00050  Individuals regularly using the internet by NU...
# 9253       tgs00052  Individuals who ordered goods or services over...
# 9296       tin00111  Enterprises having received orders online (at ...
# 9299       tin00110   Share of enterprises' turnover on e-commerce - %
# 9317       tin00116  Share of enterprises using any business softwa...
# 9402       tin00074  Percentage of the ICT sector in Gross value added
# 9404       tin00085  Percentage of the ICT sector personnel in tota...
# 9406       tin00086  Percentage change of value added by ICT sector...
# 9422      sdg_17_60  High-speed internet coverage, by type of area ...
# 9433       tipsbp10           Current account balance - 3 year average
# 9434       tipsii10  Net international investment position - annual...
# 9436       tipsbp60             Share of exports of advanced economies
# 9437       tipslm10           Nominal unit labour cost per hour worked
# 9438       tipsgo10  General government gross debt (EDP concept), c...
# 9439       tipspd22  Household debt, consolidated including Non-pro...
# 9440       tipspd30  Non-financial corporations debt, consolidated ...
# 9441       tipspc40  Household including non-profit institutions se...
# 9442       tipspc30  Non-financial corporations excluding foreign d...
# 9444       tipsun20                    Unemployment rate - annual data
# 9445       tipslm60                    Labour force participation rate
# 9449       tipsbp20              Current account balance - annual data
# 9450       tipsbp11  Current account, main components, net balance ...
# 9451       tipsbp12  Current account, main component, credit - annu...
# 9452       tipsbp13  Current account, main components, debit - annu...
# 9453       tipsbp14  Current account, main components, net balance ...
# 9454       tipsbp15  Current account, main components, credit - ann...
# 9455       tipsbp16  Current account, main components, debit - annu...
# 9457       tipsbp18                    Financial account - annual data
# 9458       tipsbp19  Financial account by components, net balance -...
# 9459       tipsbp90  Direct investment liabilities (flows) - annual...
# 9460      tipsbp100  Direct investment liabilities (stocks) - annua...
# 9461       tipsbp21  Direct investment in the reporting economy, ma...
# 9462       tipsbp22  Direct investment abroad, main components - an...
# 9464       tipsbp17                      Capital account - annual data
# 9465       tipsbp70  Net Lending/Borrowing (current and capital acc...
# 9468       tipsbp40           Current account balance - quarterly data
# 9469       tipsbp41  Current account, main components, net balance ...
# 9470       tipsbp42  Current account, main components, credit - qua...
# 9471       tipsbp43  Current account, main components, debit - quar...
# 9472       tipsbp44  Current account, main components, net balance ...
# 9473       tipsbp45  Current account, main components, credit - qua...
# 9474       tipsbp46  Current account, main components, debit - quar...
# 9476       tipsbp48                 Financial account - quarterly data
# 9477       tipsbp49  Financial account, main components - quarterly...
# 9478       tipsbp51  Direct investment in the reporting economy - q...
# 9479       tipsbp52  Direct investment in the reporting economy, ma...
# 9480       tipsbp53  Direct investment abroad - quarterly data, % o...
# 9481       tipsbp54  Direct investment abroad, main components - qu...
# 9483       tipsbp47                   Capital account - quarterly data
# 9484       tipsbp50  Net Lending/Borrowing (current and capital acc...
# 9487       tipsii12  Direct investment - annual data, million units...
# 9488       tipsii13  Direct investment assets, by instruments - ann...
# 9489       tipsii14  Direct investment liabilities, by instruments ...
# 9490       tipsii15  Portfolio investment - annual data, million un...
# 9491       tipsii16  Portfolio investment assets, by instuments - a...
# 9492       tipsii17  Portfolio investment liabilities, by instrumen...
# 9493       tipsii18  Financial derivatives and employee stock optio...
# 9494       tipsii19  Financial derivatives and employee stock optio...
# 9495       tipsii21  Other investment - annual data, million units ...
# 9496       tipsii22  Other investment by sectors - annual data, mil...
# 9498       tipsii40  Net international investment position - quarte...
# 9499       tipsii41  International investment position - quarterly ...
# 9500       tipsii42  Direct investment - quarterly data, million un...
# 9501       tipsii43  Portfolio investment - quarterly data, million...
# 9502       tipsii44  Financial derivatives and employee stock optio...
# 9503       tipsii45  Other investment - quarterly data, million uni...
# 9505       tipser11  Nominal effective exchange rate - 42 trading p...
# 9507       tipser12  Nominal effective exchange rate - euro area tr...
# 9508       tipser13  Real effective exchange rate - index, 42 tradi...
# 9510       tipsii20          Net external debt - annual data, % of GDP
# 9511       tipsii30       Net external debt - quarterly data, % of GDP
# 9512       tipsii50  Net international investment position excludin...
# 9514       tipsex11    Export market shares by items - 1 year % change
# 9515       tipsex20   Export market shares by items - % of world total
# 9516       tipsex13                     Export market shares in volume
# 9517       tipsex10            Export market shares - 3 years % change
# 9518       tipsen10    Net trade balance of energy products - % of GDP
# 9519       tipsna30         Terms of trade by items - 5 years % change
# 9520       tipsex12  Exports of high technology products as a share...
# 9522       tipsgo20  General government gross debt (EDP concept), c...
# 9523       tipsgo11  Government consolidated gross debt by componen...
# 9526       tipsfs10  Total financial sector liabilities, non-consol...
# 9527       tipsfs11  Total financial sector liabilities, by sub-sec...
# 9528       tipsfs12  Total financial sector liabilities, by sub-sec...
# 9529       tipsfs13  Total financial sector liabilities, by instrum...
# 9530       tipsfs14  Total financial sector liabilities, by instrum...
# 9531       tipsfs20  Financial sector leverage, debt to equity, non...
# 9533       tipsfs30   Total financial sector liabilities, consolidated
# 9534       tipsfs31  Total financial sector liabilities, by sub-sec...
# 9535       tipsfs32  Total financial sector liabilities, by sub-sec...
# 9536       tipsfs33  Total financial sector liabilities, by instrum...
# 9537       tipsfs34  Total financial sector liabilities, by instrum...
# 9545       tipspd10              Private sector debt, non-consolidated
# 9546       tipspd13  Private sector debt: debt securities by sector...
# 9547       tipspd14  Private sector debt: debt securities by sector...
# 9548       tipspd15  Private sector debt: loans, by sectors, non-co...
# 9549       tipspd16  Private sector debt: loans by sectors, non-con...
# 9551       tipspd20       Private sector debt, consolidated - % of GDP
# 9552       tipspd23  Private sector debt: debt securities, by secto...
# 9553       tipspd24  Private sector debt: debt securities, by secto...
# 9554       tipspd25  Private sector debt: loans, by sectors, consol...
# 9555       tipspd26  Private sector debt: loans, by sectors, consol...
# 9556       tipspd40  Household including non-profit institutions se...
# 9557       tipspd35  Non-financial corporations debt excluding fore...
# 9560       tipspc10       Private sector credit flow, non-consolidated
# 9561       tipspc13  Private sector credit flow: debt securities by...
# 9562       tipspc14  Private sector credit flow: debt securities by...
# 9563       tipspc15  Private sector credit flow: loans by sectors, ...
# 9564       tipspc16  Private sector credit flow: loans by sectors, ...
# 9566       tipspc20   Private sector credit flow, consolidated - % GDP
# 9567       tipspc23  Private sector credit flow: debt securities by...
# 9568       tipspc24  Private sector credit flow: debt securities by...
# 9569       tipspc25  Private sector credit flow: loans by sectors, ...
# 9570       tipspc26  Private sector credit flow: loans by sectors, ...
# 9572       tipsnf10  Net lending (+) /net borrowing (-), by sub-sec...
# 9573       tipsnf11  Net savings by sub-sectors - current prices, m...
# 9575       tipsun10                 Unemployment rate - 3 year average
# 9576       tipslm70  Long-term unemployment rate, % of active popul...
# 9577       tipslm80  Youth unemployment rate - % of active populati...
# 9578       tipslm90  Young people neither in employment nor in educ...
# 9579      tipslm100                                    Employment rate
# 9580       tipsun30  Unemployment rate - quarterly data, seasonally...
# 9581       tipslm15  Labour force participation rate, aged 15-64 - ...
# 9582       tipslm16    Population, aged 15-74 - EU labour force survey
# 9585       tipslm20  Nominal unit labour cost per hour worked - ann...
# 9587       tipsna70  Labour productivity per hour worked - annual data
# 9588       tipslm13  Compensation of employees - annual data, milli...
# 9589       tipsna60         Employment, domestic concept - annual data
# 9590       tipsna62          Employees, domestic concept - annual data
# 9592       tipslm40  Nominal unit labour cost (NULC) per hour worke...
# 9593       tipsna71  Real labour productivity per person employed p...
# 9594       tipslm14  Compensation of employees - quarterly data, mi...
# 9595       tipsna61  Employment, domestic concept - quarterly data,...
# 9600       tipsna50   Residential construction - annual data, % of GDP
# 9601       tipsna51  Final consumption expenditure of households an...
# 9602       tipsho50                     Building permits - annual data
# 9607       tipsho41  Final consumption expenditure of households an...
# 9609       tipslc10      People at risk of poverty or social exclusion
# 9610       tipslc20    People at risk of poverty after social transfer
# 9611       tipslc30   Severely materially and socially deprived people
# 9612       tipslc40  People living in households with very low work...
# 9614       tipsna10  Gross domestic product (GDP) at market prices ...
# 9615       tipsna15  Gross domestic product (GDP) at market prices ...
# 9616       tipsna20    Gross fixed capital formation at current prices
# ...
# 10329   tepsr_sp410  Individuals who have basic or above basic over...
# 10330     sdg_08_20  Young people neither in employment nor in educ...
# 10331      tesem060                              Gender employment gap
# 10332      tessi180       Income quintile share ratio (S80/S20) by sex
# 10334     sdg_04_60  Adult participation in learning in the past fo...
# 10335      tesem030   Tertiary educational attainment, age group 30-34
# 10336   tepsr_lm210                 Gender gap in part-time employment
# 10337     sdg_05_20                  Gender pay gap in unadjusted form
# 10340      tesem010                             Employment rate by sex
# 10341   tepsr_wc110                             Employment rate by age
# 10342      tesem120                           Unemployment rate by sex
# 10343   tepsr_wc170                           Unemployment rate by age
# 10344      tesem130                 Long-term unemployment rate by sex
# 10345   tepsr_wc310  The real gross disposable income of households...
# 10347   tepsr_wc130                               Activity rate by sex
# 10348   tepsr_wc160                               Activity rate by age
# 10349      tesem140                     Youth unemployment rate by sex
# 10350   tepsr_wc220              Employment in current job by duration
# 10351   tepsr_wc230  Labour transitions from temporary to permanent...
# 10352      tesov110             In-work at-risk-of-poverty rate by sex
# 10356      tessi010                     At-risk-of-poverty rate by sex
# 10357  tepsr_spi110  At-risk-of poverty rate for children (aged les...
# 10358   tepsr_lm420  Severe material and social deprivation rate by...
# 10359  tepsr_spi120  Severe material and social deprivation rate fo...
# 10360   tepsr_lm430  People living in households with very low work...
# 10361  tepsr_spi130  Children (aged less than 18) living in househo...
# 10363   tepsr_lm412  Children (aged less than 18) at risk of povert...
# 10364     sdg_01_10     Persons at risk of poverty or social exclusion
# 10365   tepsr_lm410  People at risk of poverty or social exclusion ...
# 10366   tepsr_lm411  People at risk of poverty or social exclusion ...
# 10367   tepsr_lm412  Children (aged less than 18) at risk of povert...
# 10368      tespm050  Impact of social transfers (excluding pensions...
# 10369   tepsr_sp200  Disability employment gap by level of activity...
# 10370      tespm140                       Housing cost overburden rate
# 10371   tepsr_sp210  Children aged less than 3 years in formal chil...
# 10372      tespm110   Self-reported unmet need for medical care by sex
# 10374   tepsr_lm440   Severe housing deprivation rate by tenure status
# 10375   tepsr_sp110         General government expenditure by function
# 10376      tespn070  Aggregate replacement ratio for pensions (excl...
# 10377   tepsr_sp310            Out-of-pocket expenditure on healthcare
# 10378   tepsr_sp320                Healthy life years at age 65 by sex
# 10380    tespm050_r  Impact of social transfers (excluding pensions...
# 10381   tepsr_lm220             Gender employment gap by NUTS 2 region
# 10382   tepsr_lm230    Gender employment gap by degree of urbanisation
# 10389      tespm151                  Inequality of income distribution
# 10390      ilc_pns4  Inequality of income distribution S80/S20 inco...
# 10391     sdg_10_41                                Income distribution
# 10392      tessi180       Income quintile share ratio (S80/S20) by sex
# 10393      tespn080  Income inequality for older people - EU-SILC s...
# 10414      tipslm70  Long-term unemployment rate, % of active popul...
# 10529      tesem180                  Gender pay gap in unadjusted form
# 10530     sdg_05_20                  Gender pay gap in unadjusted form
# 10531      tesem060                              Gender employment gap
# 10675       tqoe4a3  Employed persons being self-employed without e...
# 10683       tqoe4a3  Employed persons being self-employed without e...
# 10877      tet00003          Exports of goods and services in % of GDP
# 10878      tet00004          Imports of goods and services in % of GDP
# 10885      tec00105                      Inward FDI stocks in % of GDP
# 10886      tec00106                     Outward FDI stocks in % of GDP
# 10887      tec00107            FDI flows intensity, market integration
# 10900      eq_pop02                        Population structure by sex
# 10901      eq_pop03         Population structure by detailed age group
# 10902      eq_pop04                                  Median age by sex
# 10909      tps00178                            Foreign-born population
# 10910  yth_demo_060  Youth population on 1 January by sex, age and ...
# 10921      eq_fer05                                        Live births
# 10925      eq_mor06                                      Deaths by sex
# 10944      tespm050  Impact of social transfers (excluding pensions...
# 10945      ilc_pns5  Relative median at-risk-of-poverty gap of elde...
# 10946      tespn260  Gender differences in the aggregate replacemen...
# 10951   dsb_sprex03  Social protection expenditure on disability by...
# 10952   dsb_sprpb01  Beneficiaries of disability pensions by pensio...
# 10954   dsb_sprpb01  Beneficiaries of disability pensions by pensio...
# 10955   dsb_sprpb02        Beneficiaries of disability pensions by sex
# 10969  tepsr_spi130  Children (aged less than 18) living in househo...
# 10970     sdg_01_40  Persons living in households with very low wor...
# 10971   tepsr_lm430  People living in households with very low work...
# 10972      tipslc40  People living in households with very low work...
# 10979     sdg_11_11  Severe housing deprivation rate by poverty status
# 11022     sdg_05_20                  Gender pay gap in unadjusted form
# 11024      tesem180                  Gender pay gap in unadjusted form
# 11025     sdg_05_20                  Gender pay gap in unadjusted form
# 11032     sdg_05_30       Gender employment gap, by type of employment
# 11034   tepsr_sp200  Disability employment gap by level of activity...
# 11044   tepsr_wc230  Labour transitions from temporary to permanent...
# 11074       tqoe1c2  Employed women being in managerial positions b...
# 11112     eq_dskl07  Individuals' level of digital skills by sex an...
# 11113     eq_dskl08  Individuals' level of digital skills by countr...
# 11114     eq_dskl09  Individuals' level of digital skills by countr...
# 11121   dsb_ictiu04  Persons using the internet for telephoning or ...
# 11122   dsb_ictiu03  Persons using the internet for learning activi...
# 11123      tin00101  Individuals using the internet for seeking hea...
# 11124      tin00129  Individuals using the internet for taking part...
# 11125      tin00102  Individuals using the internet for looking for...
# 11126   dsb_ictiu06  Persons using the internet for finding informa...
# 11127   dsb_ictiu07  Persons using the internet for internet bankin...
# 11128   dsb_ictiu05  Persons using the internet for participating i...
# 11129      tin00127  Individuals using the internet for participati...
# 11130   dsb_ictiu08  Persons using the internet for seeking health ...
# 11131      tin00098  Individuals using the internet for selling goo...
# 11132      tin00095  Individuals using the internet for finding inf...
# 11133      tin00103  Individuals using the internet for doing an on...
# 11134   dsb_ictiu09  Persons using the internet for making an appoi...
# 11135      tin00094  Individuals using the internet for sending/rec...
# 11136      tin00099  Individuals using the internet for internet ba...
# 11138   dsb_icteg04  Persons using a website or app of public autho...
# 11139   dsb_icteg02  Persons using the internet to request official...
# 11140   dsb_icteg01  Persons using the internet for interaction wit...
# 11141   dsb_icteg03  Persons using the internet for making an appoi...
# 11149      eq_wdisc             Perception of discrimination in cities
# 11153     sdg_05_11  Physical and sexual violence to women by age g...
# 11178      tesem180                  Gender pay gap in unadjusted form
# 11179     sdg_05_20                  Gender pay gap in unadjusted form
# 11182       tqoe1c2  Employed women being in managerial positions b...
# 11194       tqoe3a5   Employed persons having more than one job by sex
# 11199       tqoe3b4     Employees with a flexible work schedule by sex
# 11214       tqoe4a3  Employed persons being self-employed without e...
# 11240     sdg_02_40                         Area under organic farming
# 11241         tai02           Sales of pesticides by type of pesticide
# 11242         tai03  Share of irrigable and irrigated areas in util...
# 11243         tai04  Final energy consumption by agriculture and fo...
# 11244         tai05  Share of main land types in utilised agricultu...
# 11245         tai06  Share of main livestock types in total livesto...
# 11246         tai09                            Livestock density index
# 11247     sdg_07_30                                Energy productivity
# 11248     sdg_02_60                 Ammonia emissions from agriculture
# 11249         tai07  Ammonia emissions from agriculture - % of tota...
# 11250         tai08          Greenhouse gas emissions from agriculture
# 11251         tai10  Estimated soil loss by water erosion by land c...
# 11252         tai11  Share of landcover types affected by severe er...
# 11262         tai08          Greenhouse gas emissions from agriculture
# 11266     sdg_07_10                         Primary energy consumption
# 11267     sdg_07_11                           Final energy consumption
# 11268     sdg_07_20  Final energy consumption in households per capita
# 11269      ten00123                Final energy consumption by product
# 11270      ten00124                 Final energy consumption by sector
# 11271      ten00129  Final energy consumption in industry by type o...
# 11273      ten00127  Final energy consumption in road transport by ...
# 11274      ten00125  Final energy consumption in households by type...
# 11275      ten00126  Final energy consumption in transport by type ...
# 11286      ttr00005                            Goods transport by road
# 11291      ttr00001      Volume of passenger transport relative to GDP
# 11292      ten00126  Final energy consumption in transport by type ...
# 11293      ten00127  Final energy consumption in road transport by ...
# 11303      tag00016                           Number of bovine animals
# 11304      tag00014                               Number of dairy cows
# 11305         tai06  Share of main livestock types in total livesto...
# 11306         tai09                            Livestock density index
# 11308      tag00124               Agricultural holdings with livestock
# 11310      tgs00045                Animal populations by NUTS 2 region
# 11329      ten00139                                       Energy taxes
# 11343         tai03  Share of irrigable and irrigated areas in util...
# 11349      ten00001          Water resources: long-term annual average
# 11350      ten00006                  Water abstracted by sector of use
# 11364  yth_educ_020  Population aged 30-34 with tertiary educationa...
# 11365  yth_educ_030  Young people aged 20-24 with at least upper se...
# 11366      tps00065  At least upper secondary educational attainmen...
# 11367      tps00186  At least upper secondary educational attainmen...
# 11368      tps00197  At most lower secondary educational attainment...
# 11370      tgs00109  Tertiary educational attainment, age group 25-...
# 11371      tgs00105  Tertiary educational attainment, age group 25-...
# 11379      tps00215   Exposure of VET graduates to work-based learning
# 11386      tgs00106  Early leavers from education and training by s...
# 11397      tsc00025   Human resources in science and technology (HRST)
# 11401      tgs00038  Human resources in science and technology (HRS...
# 11408   dsb_ictiu01  Persons using the internet in the past 12 mont...
# 11409      tin00028                        Internet use by individuals
# 11410      tin00093       Individuals who have never used the internet
# 11412   dsb_ictiu04  Persons using the internet for telephoning or ...
# 11413   dsb_ictiu03  Persons using the internet for learning activi...
# 11414      tin00101  Individuals using the internet for seeking hea...
# 11415      tin00129  Individuals using the internet for taking part...
# 11416      tin00102  Individuals using the internet for looking for...
# 11417   dsb_ictiu06  Persons using the internet for finding informa...
# 11418   dsb_ictiu07  Persons using the internet for internet bankin...
# 11419   dsb_ictiu05  Persons using the internet for participating i...
# 11420      tin00127  Individuals using the internet for participati...
# 11421   dsb_ictiu08  Persons using the internet for seeking health ...
# 11422      tin00098  Individuals using the internet for selling goo...
# 11423      tin00095  Individuals using the internet for finding inf...
# 11424      tin00103  Individuals using the internet for doing an on...
# 11425   dsb_ictiu09  Persons using the internet for making an appoi...
# 11426      tin00094  Individuals using the internet for sending/rec...
# 11427      tin00099  Individuals using the internet for internet ba...
# 11429      tin00092          Individuals frequently using the internet
# 11430      tin00091           Individuals regularly using the internet
# 11431   dsb_ictiu02  Persons regularly using the internet by level ...
# 11435   tepsr_sp410  Individuals who have basic or above basic over...
# 11436     sdg_04_70  Share of individuals having at least basic dig...
# 11462       tqoe4a3  Employed persons being self-employed without e...
# 11465       tqoe3a5   Employed persons having more than one job by sex
# 11471       tqoe1c2  Employed women being in managerial positions b...
# 11484       tqoe4a3  Employed persons being self-employed without e...
# 11510      tps00071      Hours worked per week of full-time employment
# 11534      tps00053               Employment rates of recent graduates
# 11551      tsc00003  Total researchers by sector of performance - h...
# 11552      tsc00004  Total researchers by sector of performance - f...
# 11554      tsc00002  Research and development personnel by sector o...
# 11556      tsc00006          Share of women researchers in all sectors
# 11557      tsc00005  Share of women researchers by sector of perfor...
# 11565      tgs00043        Researchers in all sectors by NUTS 2 region
# 11571      tsc00011  Employment in high- and medium-high technology...
# 11577      tgs00039   Employment in high-tech sectors by NUTS 2 region
# 11596  ei_lmjv_q_r2                  Job vacancy rate - quarterly data
# 11597      tps00172  Job vacancies in number and % - NACE Rev. 2, B...
# 11638  yth_educ_060  Participation rate in non-formal education and...
# 11742  yth_demo_060  Youth population on 1 January by sex, age and ...
# 11743  yth_demo_070  Young immigrants by sex, age and country of birth
# 11744  yth_demo_080   Young emigrants by sex, age and country of birth
# 11754   tepsr_lm412  Children (aged less than 18) at risk of povert...
# 11755  tepsr_spi110  At-risk-of poverty rate for children (aged les...
# 11756  tepsr_spi130  Children (aged less than 18) living in househo...
# 11757  tepsr_spi120  Severe material and social deprivation rate fo...
# 11769      tps00027                              Infant mortality rate
# 11773      tps00185        Formal child care by duration and age group
# 11774   tepsr_sp210  Children aged less than 3 years in formal chil...
# 11799      tesem070             Youth employment rate, age group 20-29
# 11812      tespm080                   Youth unemployment ratio (15-24)
# 11818  yth_demo_040  Young people by educational attainment level, ...
# 11820     sdg_04_10   Early leavers from education and training by sex
# 11821      tesem020  Early leavers from education and training, age...
# 11822  yth_educ_020  Population aged 30-34 with tertiary educationa...
# 11823  yth_educ_030  Young people aged 20-24 with at least upper se...
# 11824  yth_educ_060  Participation rate in non-formal education and...
# 11830     sdg_02_10              Obesity rate by body mass index (BMI)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

na = df[df['code'].str.startswith("na")][['title_clean', 'code', 'type','values','indent', 'row_id']]

# %%
def classificazione_codice(code):
    if code.startswith("nama_10r"):
        return "Conti regionali"
    elif code.startswith("nama_10"):
        return "Conti nazionali annuali"
    elif code.startswith("namq_10"):
        return "Conti nazionali trimestrali"
    elif code.startswith("naio_10"):
        return "Conti input-output"
    elif code.startswith("nasa_10") or code.startswith("nasq_10"):
        return "Conti satellite"
    elif code.startswith("naidq_10") or code.startswith("naida_10") or code.startswith("naid_10"):
        return "Conti disaggregati"
    elif code.startswith("naidsa_10") or code.startswith("naidsq_10"):
        return "Conti disaggregati (destagionalizzati)"
    else:
        return "Altro"

na['argomento'] = na['code'].apply(classificazione_codice)
na
# Out:
#                                              title_clean              code  \
# 62     Gross domestic product (GDP) and main componen...       namq_10_gdp
# 64     Household final consumption expenditure by dur...       namq_10_fcs
# 65               Exports and imports by counterpart area       namq_10_exi
# 67     Gross value added and income by main industry ...       namq_10_a10
# 68      Gross fixed capital formation by main asset type       namq_10_an6
# 69     Employment by main industry (NACE Rev.2) - nat...     namq_10_a10_e
# 73                       Key indicators - quarterly data        nasq_10_ki
# 74           Non-financial transactions - quarterly data     nasq_10_nf_tr
# 75     Gross domestic product (GDP) and main componen...       nama_10_gdp
# 225    Gross domestic product (GDP) at current market...     nama_10r_2gdp
# 228    Average annual population to calculate regiona...  nama_10r_3popgdp
# 229    Gross domestic product (GDP) at current market...     nama_10r_3gdp
# 230    Gross domestic product (GDP) and Gross value a...   nama_10r_2gvagr
# 233    Gross value added at basic prices by NUTS 3 re...     nama_10r_3gva
# 234    Gross fixed capital formation by NUTS 2 region...    nama_10r_2gfcf
# 235           Compensation of employees by NUTS 2 region     nama_10r_2coe
# 236       Employment (thousand persons) by NUTS 3 region  nama_10r_3empers
# 237    Employment (thousand hours worked) by NUTS 2 r...   nama_10r_2emhrw
# 238                Income of households by NUTS 2 region   nama_10r_2hhinc
# 636    Gross domestic product (GDP) at current market...     nama_10r_3gdp
# 637    Gross value added at basic prices by NUTS 3 re...     nama_10r_3gva
# 638       Employment (thousand persons) by NUTS 3 region  nama_10r_3empers
# 1283                        National accounts (ESA 2010)              na10
# 1284                            Annual national accounts            nama10
# 1285                                  GDP and components        nama_10_ma
# 1286   Gross domestic product (GDP) and main componen...       nama_10_gdp
# 1306   Gross value added and income by main industry ...       nama_10_a10
# 1307   Gross value added and income by detailed indus...       nama_10_a64
# 1308             Exports and imports by counterpart area       nama_10_exi
# 1309   Gross domestic product (GDP) and main componen...        nama_10_pc
# 1314              Gross national income (GNI) per capita        nama_10_pp
# 1315         Final consumption expenditure of households       nama_10_hfc
# 1316   Household final consumption expenditure by dur...       nama_10_fcs
# 1317   Household final consumption expenditure by pur...      nama_10_cp18
# 1318   Household final consumption expenditure by pur...    nama_10_co3_p3
# 1320                        Capital formation and stocks       nama_10_nfa
# 1321    Gross fixed capital formation by main asset type       nama_10_an6
# 1323   Capital formation by industry (NACE Rev.2) and...    nama_10_a64_p5
# 1324   Capital stocks by industry (NACE Rev.2) and de...    nama_10_nfa_st
# 1325    Capital stocks by sector and detailed asset type    nama_10_nfa_bs
# 1326      Population and employment in national accounts       nama_10_e_p
# 1327       Population and employment - national accounts        nama_10_pe
# 1331   Employment by main industry (NACE Rev.2) - nat...     nama_10_a10_e
# 1335   Employment by detailed industry (NACE Rev.2) -...     nama_10_a64_e
# 1336      Average full time adjusted salary per employee       nama_10_fte
# 1337                          Regional economic accounts        nama_10reg
# 1338                   Gross domestic product indicators      nama_10r_gdp
# 1339   Gross domestic product (GDP) at current market...     nama_10r_2gdp
# 1340   Gross domestic product (GDP) at current market...     nama_10r_3gdp
# 1341   Gross domestic product (GDP) and Gross value a...   nama_10r_2gvagr
# 1342   Average annual population to calculate regiona...  nama_10r_3popgdp
# 1343                       Branch and Household accounts     nama_10r_brch
# 1344   Gross value added at basic prices by NUTS 3 re...     nama_10r_3gva
# 1345   Gross fixed capital formation by NUTS 2 region...    nama_10r_2gfcf
# 1346          Compensation of employees by NUTS 2 region     nama_10r_2coe
# 1347      Employment (thousand persons) by NUTS 3 region  nama_10r_3empers
# 1348   Employment (thousand hours worked) by NUTS 2 r...   nama_10r_2emhrw
# 1349               Income of households by NUTS 2 region   nama_10r_2hhinc
# 1352                     Labour and capital productivity      nama_10_prod
# 1353   Labour and capital productivity for total econ...       nama_10_lpc
# 1354           Labour productivity and unit labour costs    nama_10_lp_ulc
# 1361   Labour productivity and unit labour costs by i...    nama_10_lp_a21
# 1362   Capital stock based productivity indicators by...    nama_10_cp_a21
# 1363                       Labour productivity by region       nama_10r_lp
# 1364        Nominal Labour productivity by NUTS 2 region     nama_10r_2nlp
# 1365        Nominal Labour productivity by NUTS 3 region     nama_10r_3nlp
# 1366           Real Labour productivity by NUTS 2 region     nama_10r_2rlp
# 1367   Compensation per employee and hours worked per...    nama_10r_2lp10
# 1368                         Quarterly national accounts           namq_10
# 1369                                  GDP and components        namq_10_ma
# 1370   Gross domestic product (GDP) and main componen...       namq_10_gdp
# 1384   Gross value added and income by main industry ...       namq_10_a10
# 1410   Household final consumption expenditure by dur...       namq_10_fcs
# 1413             Exports and imports by counterpart area       namq_10_exi
# 1414   Gross domestic product (GDP) and main componen...        namq_10_pc
# 1415      Population and employment in national accounts       namq_10_e_p
# 1416       Population and employment - national accounts        namq_10_pe
# 1417   Employment by main industry (NACE Rev.2) - nat...     namq_10_a10_e
# 1424           Labour productivity and capital formation     namq_10_lp_cf
# 1425           Labour productivity and unit labour costs    namq_10_lp_ulc
# 1428    Gross fixed capital formation by main asset type       namq_10_an6
# 1431                 Supply, use and input-output tables           naio_10
# 1432        National supply, use and input-output tables         naio_10_n
# 1433   Supply, use and input-output tables  - current...        naio_10_cp
# 1434   Supply table at basic prices incl. transformat...      naio_10_cp15
# 1435                     Use table at purchasers' prices      naio_10_cp16
# 1436                           Use table at basic prices    naio_10_cp1610
# 1437                Table of trade and transport margins    naio_10_cp1620
# 1438            Table of taxes less subsidies on product    naio_10_cp1630
# 1439   Symmetric input-output table at basic prices (...    naio_10_cp1700
# 1440   Symmetric input-output table at basic prices (...    naio_10_cp1750
# 1441   Supply, use and input-output tables - previous...       naio_10_pyp
# 1442   Supply table at basic prices incl. transformat...     naio_10_pyp15
# 1443   Use table at purchasers' prices (previous year...     naio_10_pyp16
# 1444   Use table at basic prices (previous years prices)   naio_10_pyp1610
# 1445   Table of trade and transport margins (previous...   naio_10_pyp1620
# 1446   Table of taxes less subsidies on products (pre...   naio_10_pyp1630
# 1447   Symmetric input-output table at basic prices (...   naio_10_pyp1700
# 1448   Symmetric input-output table at basic prices (...   naio_10_pyp1750
# 1449   EU inter-country supply, use and input-output ...         naio_10_f
# 1450   EU inter-country supply, use and input-output ...       naio_10_fcp
# 1451   EU inter-country supply table at basic prices ...    naio_10_fcp_s1
# 1452   EU inter-country supply table at basic prices ...    naio_10_fcp_s2
# 1453   EU inter-country supply table at basic prices ...    naio_10_fcp_s3
# 1454   EU inter-country use table at basic prices (20...    naio_10_fcp_u1
# 1455   EU inter-country use table at basic prices (20...    naio_10_fcp_u2
# 1456   EU inter-country use table at basic prices (20...    naio_10_fcp_u3
# 1457   EU inter-country input-output table at basic p...   naio_10_fcp_ip1
# 1458   EU inter-country input-output table at basic p...   naio_10_fcp_ip2
# 1459   EU inter-country input-output table at basic p...   naio_10_fcp_ip3
# 1460   EU inter-country input-output table at basic p...   naio_10_fcp_ii1
# 1461   EU inter-country input-output table at basic p...   naio_10_fcp_ii2
# 1462   EU inter-country input-output table at basic p...   naio_10_fcp_ii3
# 1463   Macroeconomic globalisation indicators based o...        naio_10_fg
# 1464            Imports by industry (FIGARO application)      naio_10_fgti
# 1465            Exports by industry (FIGARO application)      naio_10_fgte
# 1466   Domestic value added in exports - EU perspecti...      naio_10_fgde
# 1467   Domestic value added in exports - EU country p...      naio_10_fgdm
# 1468   Foreign value added in exports by exporting co...    naio_10_fgfeie
# 1469   Foreign value added in exports by country of o...    naio_10_fgfoie
# 1470   Foreign value added in exports by country of o...    naio_10_fgfoee
# 1471   Foreign value added in exports by exporting co...    naio_10_fgfeim
# 1472   Foreign value added in exports by country of o...    naio_10_fgfoim
# 1473   Foreign value added in exports by country of o...    naio_10_fgfoem
# 1474   Domestic value added in foreign final use (FIG...      naio_10_fgdf
# 1475   Foreign value added in domestic final use (FIG...      naio_10_fgfd
# 1476   Global value chain participation - EU perspect...    naio_10_fggvce
# 1477   Global value chain participation - EU country ...    naio_10_fggvcm
# 1478       Trading partner exposure (FIGARO application)     naio_10_fgtex
# 1479   Domestic employment in exports - EU perspectiv...     naio_10_fgdee
# 1480   Domestic employment in exports - EU country pe...     naio_10_fgdem
# 1481   Domestic employment in foreign final use (FIGA...     naio_10_fgdfe
# 1482            Environmental footprints based on FIGARO      naio_10_fenv
# 1490                   Annual sector accounts (ESA 2010)           nasa_10
# 1491                                               -----          nasa_10_
# 1492            Non-financial transactions - annual data     nasa_10_nf_tr
# 1494                          Financial flows and stocks         nasa_10_f
# 1495              Financial balance sheets - annual data      nasa_10_f_bs
# 1499                Financial transactions - annual data      nasa_10_f_tr
# 1502                   Revaluation account - annual data      nasa_10_f_gl
# 1503               Other changes in volume - annual data      nasa_10_f_oc
# 1504   Financial accounts: counterpart information --...      nasa_10_f_cp
# 1505                        Key indicators - annual data        nasa_10_ki
# 1509                Quarterly sector accounts (ESA 2010)           nasq_10
# 1510                                               -----          nasq_10_
# 1511         Non-financial transactions - quarterly data     nasq_10_nf_tr
# 1512                          Financial flows and stocks         nasq_10_f
# 1513           Financial balance sheets - quarterly data      nasq_10_f_bs
# 1514             Financial transactions - quarterly data      nasq_10_f_tr
# 1515                Revaluation account - quarterly data      nasq_10_f_gl
# 1516           Other changes in volume -  quarterly data      nasq_10_f_oc
# 1517   Financial accounts: counterpart information - ...      nasq_10_f_cp
# 1518                     Key indicators - quarterly data        nasq_10_ki
# 1519                       Pensions in national accounts      nasa_10_pens
# 1520   Accrued-to-date pension entitlements in social...     nasa_10_pens1
# 1521   Sensitivity analysis of accrued-to-date pensio...     nasa_10_pens2
# 1522   National accounts - international data coopera...           naid_10
# 1523   Annual national accounts - international data ...          naida_10
# 1524   GDP and main aggregates - international data c...      naida_10_gdp
# 1525   Gross value added by A*10 industry- internatio...      naida_10_a10
# 1526   Employment and population - international data...       naida_10_pe
# 1527   Quarterly national accounts - international da...          naidq_10
# 1528   GDP and main aggregates - international data c...      naidq_10_gdp
# 1529   Gross value added by A*10 industry- internatio...      naidq_10_a10
# 1530   Employment and population - international data...       naidq_10_pe
# 1531   Annual sector accounts (ESA 2010) - internatio...         naidsa_10
# 1532   Non-financial transactions - selected internat...   naidsa_10_nf_tr
# 1533   Financial balance sheets - international data ...    naidsa_10_f_bs
# 1534   Financial transactions - international data co...    naidsa_10_f_tr
# 1535   Quarterly sector accounts (ESA 2010) - interna...         naidsq_10
# 1536   Non-financial transactions - selected internat...   naidsq_10_nf_tr
# 1537   Financial balance sheets - international data ...    naidsq_10_f_bs
# 1538   Financial transactions - international data co...    naidsq_10_f_tr
# 6085   Household final consumption expenditure by pur...    nama_10_co3_p3
# 9417   Capital stocks by industry (NACE Rev.2) and de...    nama_10_nfa_st
# 10049  Gross domestic product (GDP) at current market...     nama_10r_2gdp
# 10399  Gross domestic product (GDP) and main componen...        nama_10_pc
#
#           type      values  indent  row_id  \
# 62     dataset   7892886.0      20      63
# 64     dataset   1047860.0      20      65
# 65     dataset    671376.0      20      66
# 67     dataset   5683144.0      20      68
# 68     dataset   2654625.0      20      69
# 69     dataset   3381631.0      20      70
# 73     dataset     24575.0      20      74
# 74     dataset   3224131.0      20      75
# 75     dataset   1050045.0      16      76
# 225    dataset     71581.0      20     226
# 228    dataset     40358.0      20     229
# 229    dataset    279563.0      20     230
# 230    dataset     38072.0      20     231
# 233    dataset   1194282.0      20     234
# 234    dataset    281244.0      20     235
# 235    dataset    281024.0      20     236
# 236    dataset   1355231.0      20     237
# 237    dataset    381447.0      20     238
# 238    dataset    285294.0      20     239
# 636    dataset    279563.0      20     637
# 637    dataset   1194282.0      20     638
# 638    dataset   1355231.0      20     639
# 1283    folder         NaN       8    1284
# 1284    folder         NaN      12    1285
# 1285    folder         NaN      16    1286
# 1286   dataset   1050045.0      20    1287
# 1306   dataset    823831.0      20    1307
# 1307   dataset   8193585.0      20    1308
# 1308   dataset     84050.0      20    1309
# 1309   dataset    133457.0      20    1310
# 1314   dataset       112.0      20    1315
# 1315    folder         NaN      16    1316
# 1316   dataset    208058.0      20    1317
# 1317   dataset   1273385.0      20    1318
# 1318   dataset   1889486.0      20    1319
# 1320    folder         NaN      16    1321
# 1321   dataset    388262.0      20    1322
# 1323   dataset  17285070.0      20    1324
# 1324   dataset   8630848.0      20    1325
# 1325   dataset    105678.0      20    1326
# 1326    folder         NaN      16    1327
# 1327   dataset     15901.0      20    1328
# 1331   dataset    370595.0      20    1332
# 1335   dataset   1232518.0      20    1336
# 1336   dataset      1504.0      20    1337
# 1337    folder         NaN      16    1338
# 1338    folder         NaN      20    1339
# 1339   dataset     71581.0      24    1340
# 1340   dataset    279563.0      24    1341
# 1341   dataset     38072.0      24    1342
# 1342   dataset     40358.0      24    1343
# 1343    folder         NaN      20    1344
# 1344   dataset   1194282.0      24    1345
# 1345   dataset    281244.0      24    1346
# 1346   dataset    281024.0      24    1347
# 1347   dataset   1355231.0      24    1348
# 1348   dataset    381447.0      24    1349
# 1349   dataset    285294.0      24    1350
# 1352    folder         NaN      16    1353
# 1353    folder         NaN      20    1354
# 1354   dataset     59846.0      24    1355
# 1361   dataset    499022.0      24    1362
# 1362   dataset    370738.0      24    1363
# 1363    folder         NaN      20    1364
# 1364   dataset     54984.0      24    1365
# 1365   dataset    111186.0      24    1366
# 1366   dataset     33385.0      24    1367
# 1367   dataset    432832.0      24    1368
# 1368    folder         NaN      12    1369
# 1369    folder         NaN      16    1370
# 1370   dataset   7892886.0      20    1371
# 1384   dataset   5683144.0      20    1385
# 1410   dataset   1047860.0      20    1411
# 1413   dataset    671376.0      20    1414
# 1414   dataset    364931.0      20    1415
# 1415    folder         NaN      16    1416
# 1416   dataset    163305.0      20    1417
# 1417   dataset   3381631.0      20    1418
# 1424    folder         NaN      16    1425
# 1425   dataset    117147.0      20    1426
# 1428   dataset   2654625.0      20    1429
# 1431    folder         NaN      12    1432
# 1432    folder         NaN      16    1433
# 1433    folder         NaN      20    1434
# 1434   dataset   5320489.0      24    1435
# 1435   dataset   5964832.0      24    1436
# 1436   dataset  13247079.0      24    1437
# 1437   dataset   3330857.0      24    1438
# 1438   dataset   3308381.0      24    1439
# 1439   dataset   7728026.0      24    1440
# 1440   dataset   3839980.0      24    1441
# 1441    folder         NaN      20    1442
# 1442   dataset   3280296.0      24    1443
# 1443   dataset   3863636.0      24    1444
# 1444   dataset   4809528.0      24    1445
# 1445   dataset   1688980.0      24    1446
# 1446   dataset   1662066.0      24    1447
# 1447   dataset    917722.0      24    1448
# 1448   dataset    670586.0      24    1449
# 1449    folder         NaN      16    1450
# 1450    folder         NaN      20    1451
# 1451   dataset  43335680.0      24    1452
# 1452   dataset  43335680.0      24    1453
# 1453   dataset  26001408.0      24    1454
# 1454   dataset  46816500.0      24    1455
# 1455   dataset  46816500.0      24    1456
# 1456   dataset  28089900.0      24    1457
# 1457   dataset  46816500.0      24    1458
# 1458   dataset  46816500.0      24    1459
# 1459   dataset  28089900.0      24    1460
# 1460   dataset  46816500.0      24    1461
# 1461   dataset  46816500.0      24    1462
# 1462   dataset  28089900.0      24    1463
# 1463    folder         NaN      20    1464
# 1464   dataset   1425684.0      24    1465
# 1465   dataset   1425684.0      24    1466
# 1466   dataset  15492204.0      24    1467
# 1467   dataset   1329224.0      24    1468
# 1468   dataset    553644.0      24    1469
# 1469   dataset    395200.0      24    1470
# 1470   dataset    553644.0      24    1471
# 1471   dataset   3986944.0      24    1472
# 1472   dataset   2372188.0      24    1473
# 1473   dataset   3986944.0      24    1474
# 1474   dataset   1328860.0      24    1475
# 1475   dataset   1328860.0      24    1476
# 1476   dataset      1092.0      24    1477
# 1477   dataset      1053.0      24    1478
# 1478   dataset    544388.0      24    1479
# 1479   dataset  15492204.0      24    1480
# 1480   dataset   1329224.0      24    1481
# 1481   dataset   1329224.0      24    1482
# 1482    folder         NaN      20    1483
# 1490    folder         NaN      12    1491
# 1491    folder         NaN      16    1492
# 1492   dataset   2038038.0      20    1493
# 1494    folder         NaN      16    1495
# 1495   dataset   9538482.0      20    1496
# 1499   dataset   8527886.0      20    1500
# 1502   dataset   5150046.0      20    1503
# 1503   dataset   4812854.0      20    1504
# 1504   dataset   5395949.0      20    1505
# 1505   dataset     19642.0      16    1506
# 1509    folder         NaN      12    1510
# 1510    folder         NaN      16    1511
# 1511   dataset   3224131.0      20    1512
# 1512    folder         NaN      16    1513
# 1513   dataset   8373894.0      20    1514
# 1514   dataset   8319306.0      20    1515
# 1515   dataset   1348514.0      20    1516
# 1516   dataset   7413704.0      20    1517
# 1517   dataset  25468818.0      20    1518
# 1518   dataset     24575.0      16    1519
# 1519    folder         NaN      12    1520
# 1520   dataset     25395.0      16    1521
# 1521   dataset     20483.0      16    1522
# 1522    folder         NaN      12    1523
# 1523    folder         NaN      16    1524
# 1524   dataset    305702.0      20    1525
# 1525   dataset    115991.0      20    1526
# 1526   dataset     18271.0      20    1527
# 1527    folder         NaN      16    1528
# 1528   dataset    970709.0      20    1529
# 1529   dataset    404690.0      20    1530
# 1530   dataset     67190.0      20    1531
# 1531    folder         NaN      16    1532
# 1532   dataset   1882415.0      20    1533
# 1533   dataset   5124483.0      20    1534
# 1534   dataset   5111643.0      20    1535
# 1535    folder         NaN      16    1536
# 1536   dataset   3079954.0      20    1537
# 1537   dataset   8956057.0      20    1538
# 1538   dataset   8272101.0      20    1539
# 6085   dataset   1889486.0      16    6086
# 9417   dataset   8630848.0      16    9418
# 10049  dataset     71581.0      16   10050
# 10399  dataset    133457.0      20   10400
#
#                                     argomento
# 62                Conti nazionali trimestrali
# 64                Conti nazionali trimestrali
# 65                Conti nazionali trimestrali
# 67                Conti nazionali trimestrali
# 68                Conti nazionali trimestrali
# 69                Conti nazionali trimestrali
# 73                            Conti satellite
# 74                            Conti satellite
# 75                    Conti nazionali annuali
# 225                           Conti regionali
# 228                           Conti regionali
# 229                           Conti regionali
# 230                           Conti regionali
# 233                           Conti regionali
# 234                           Conti regionali
# 235                           Conti regionali
# 236                           Conti regionali
# 237                           Conti regionali
# 238                           Conti regionali
# 636                           Conti regionali
# 637                           Conti regionali
# 638                           Conti regionali
# 1283                                    Altro
# 1284                                    Altro
# 1285                  Conti nazionali annuali
# 1286                  Conti nazionali annuali
# 1306                  Conti nazionali annuali
# 1307                  Conti nazionali annuali
# 1308                  Conti nazionali annuali
# 1309                  Conti nazionali annuali
# 1314                  Conti nazionali annuali
# 1315                  Conti nazionali annuali
# 1316                  Conti nazionali annuali
# 1317                  Conti nazionali annuali
# 1318                  Conti nazionali annuali
# 1320                  Conti nazionali annuali
# 1321                  Conti nazionali annuali
# 1323                  Conti nazionali annuali
# 1324                  Conti nazionali annuali
# 1325                  Conti nazionali annuali
# 1326                  Conti nazionali annuali
# 1327                  Conti nazionali annuali
# 1331                  Conti nazionali annuali
# 1335                  Conti nazionali annuali
# 1336                  Conti nazionali annuali
# 1337                          Conti regionali
# 1338                          Conti regionali
# 1339                          Conti regionali
# 1340                          Conti regionali
# 1341                          Conti regionali
# 1342                          Conti regionali
# 1343                          Conti regionali
# 1344                          Conti regionali
# 1345                          Conti regionali
# 1346                          Conti regionali
# 1347                          Conti regionali
# 1348                          Conti regionali
# 1349                          Conti regionali
# 1352                  Conti nazionali annuali
# 1353                  Conti nazionali annuali
# 1354                  Conti nazionali annuali
# 1361                  Conti nazionali annuali
# 1362                  Conti nazionali annuali
# 1363                          Conti regionali
# 1364                          Conti regionali
# 1365                          Conti regionali
# 1366                          Conti regionali
# 1367                          Conti regionali
# 1368              Conti nazionali trimestrali
# 1369              Conti nazionali trimestrali
# 1370              Conti nazionali trimestrali
# 1384              Conti nazionali trimestrali
# 1410              Conti nazionali trimestrali
# 1413              Conti nazionali trimestrali
# 1414              Conti nazionali trimestrali
# 1415              Conti nazionali trimestrali
# 1416              Conti nazionali trimestrali
# 1417              Conti nazionali trimestrali
# 1424              Conti nazionali trimestrali
# 1425              Conti nazionali trimestrali
# 1428              Conti nazionali trimestrali
# 1431                       Conti input-output
# 1432                       Conti input-output
# 1433                       Conti input-output
# 1434                       Conti input-output
# 1435                       Conti input-output
# 1436                       Conti input-output
# 1437                       Conti input-output
# 1438                       Conti input-output
# 1439                       Conti input-output
# 1440                       Conti input-output
# 1441                       Conti input-output
# 1442                       Conti input-output
# 1443                       Conti input-output
# 1444                       Conti input-output
# 1445                       Conti input-output
# 1446                       Conti input-output
# 1447                       Conti input-output
# 1448                       Conti input-output
# 1449                       Conti input-output
# 1450                       Conti input-output
# 1451                       Conti input-output
# 1452                       Conti input-output
# 1453                       Conti input-output
# 1454                       Conti input-output
# 1455                       Conti input-output
# 1456                       Conti input-output
# 1457                       Conti input-output
# 1458                       Conti input-output
# 1459                       Conti input-output
# 1460                       Conti input-output
# 1461                       Conti input-output
# 1462                       Conti input-output
# 1463                       Conti input-output
# 1464                       Conti input-output
# 1465                       Conti input-output
# 1466                       Conti input-output
# 1467                       Conti input-output
# 1468                       Conti input-output
# 1469                       Conti input-output
# 1470                       Conti input-output
# 1471                       Conti input-output
# 1472                       Conti input-output
# 1473                       Conti input-output
# 1474                       Conti input-output
# 1475                       Conti input-output
# 1476                       Conti input-output
# 1477                       Conti input-output
# 1478                       Conti input-output
# 1479                       Conti input-output
# 1480                       Conti input-output
# 1481                       Conti input-output
# 1482                       Conti input-output
# 1490                          Conti satellite
# 1491                          Conti satellite
# 1492                          Conti satellite
# 1494                          Conti satellite
# 1495                          Conti satellite
# 1499                          Conti satellite
# 1502                          Conti satellite
# 1503                          Conti satellite
# 1504                          Conti satellite
# 1505                          Conti satellite
# 1509                          Conti satellite
# 1510                          Conti satellite
# 1511                          Conti satellite
# 1512                          Conti satellite
# 1513                          Conti satellite
# 1514                          Conti satellite
# 1515                          Conti satellite
# 1516                          Conti satellite
# 1517                          Conti satellite
# 1518                          Conti satellite
# 1519                          Conti satellite
# 1520                          Conti satellite
# 1521                          Conti satellite
# 1522                       Conti disaggregati
# 1523                       Conti disaggregati
# 1524                       Conti disaggregati
# 1525                       Conti disaggregati
# 1526                       Conti disaggregati
# 1527                       Conti disaggregati
# 1528                       Conti disaggregati
# 1529                       Conti disaggregati
# 1530                       Conti disaggregati
# 1531   Conti disaggregati (destagionalizzati)
# 1532   Conti disaggregati (destagionalizzati)
# 1533   Conti disaggregati (destagionalizzati)
# 1534   Conti disaggregati (destagionalizzati)
# 1535   Conti disaggregati (destagionalizzati)
# 1536   Conti disaggregati (destagionalizzati)
# 1537   Conti disaggregati (destagionalizzati)
# 1538   Conti disaggregati (destagionalizzati)
# 6085                  Conti nazionali annuali
# 9417                  Conti nazionali annuali
# 10049                         Conti regionali
# 10399                 Conti nazionali annuali
